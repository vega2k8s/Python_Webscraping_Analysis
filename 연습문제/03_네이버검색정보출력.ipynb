# %%
import requests
import os
from dotenv import load_dotenv
from pprint import pprint

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret,
}

# query string 문자열을 dict 선언
payload = {
    'query': '파이썬',
    'display': 10,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/book.json' #?query=파이썬&display=100&sort=sim

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기
items_data = res.json()['items']

pprint(items_data)
# Out:
# [{'author': '문현일',
#   'description': '“파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”\n'
#                  '나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등 \n'
#                  '생활 속  15가지 파이썬 프로젝트를 직접 완성해 보며 재미있게 실전 경험 쌓기!\n'
#                  '\n'
#                  'QR 코드, 이미지 콜라주 등 일상과 가까운 생활형 프로젝트부터 부동산, 경제지표, 시가총액 같은 실용적인 '
#                  '데이터를 다루는 프로젝트, LLM, 멀티모달 AI와 TTS 등 최신 기술까지! 폭넓은 주제를 통해 흥미롭게 '
#                  '따라 해 보세요.\n'
#                  '\n'
#                  '●\t 주식 & 경제 데이터 분석 - 시가총액, 기준금리, 주요 경제지표 데이터 분석 및 시각화하기\n'
#                  '●\t 부동산 실거래가 분석 - 지역별 단위면적당 아파트 매매 실거래가 평균 지도로 만들기\n'
#                  '●\t 멀티모달 AI & 챗봇 개발 - 생성형 AI와 챗봇을 활용한 실시간 영자 신문 스크레이핑\n'
#                  '●\t 웹 자동화 & 크롤링 - 연관 키워드 분석을 통한 연령별, 성별 쇼핑 트렌드 분석\n'
#                  '●\t 게임 & GUI 개발 - 슬라이딩 퍼즐, 영어 받아쓰기 앱으로 직접 만들어 보는 인터랙티브 프로젝트',
#   'discount': '23400',
#   'image': 'https://shopping-phinf.pstatic.net/main_5285933/52859338841.20250209071357.jpg',
#   'isbn': '9791169213271',
#   'link': 'https://search.shopping.naver.com/book/catalog/52859338841',
#   'pubdate': '20250214',
#   'publisher': '한빛미디어',
#   'title': '혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 '
#            '유튜브 강의, 오픈 채팅 제공)'},
#  {'author': '윤인성',
#   'description': '혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서\n'
#                  '\n'
#                  '『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 '
#                  '따라갈 수 있는 친절한 설명과 단계별 학습은 그대로! 혼자 공부하더라도 체계적으로 계획을 세워 학습할 수 '
#                  '있도록 ‘혼공 계획표’를 새롭게 추가했습니다. 또한 입문자가 자주 물어보는 질문과 오류 해결 방법을 '
#                  '적재적소에 배치하여 예상치 못한 문제에 부딪혀도 좌절하지 않고 끝까지 완독할 수 있도록 도와줍니다. 단순한 '
#                  '문법 암기와 코딩 따라하기에 지쳤다면, 새로운 혼공파와 함께 ‘누적 예제’와 ‘도전 문제’로 프로그래밍의 '
#                  '신세계를 경험해 보세요! 배운 내용을 씹고 뜯고 맛보고 즐기다 보면 응용력은 물론 알고리즘 사고력까지 키워 '
#                  '코딩 실력이 쑥쑥 성장할 것입니다.\n'
#                  '\n'
#                  '이 책은 독학으로 파이썬을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘 '
#                  '모르는지조차 모르는 입문자의 막연한 마음에 십분 공감하여 과외 선생님이 알려주듯 친절하게, 핵심적인 내용만 '
#                  '콕콕 집어줍니다. 책의 첫 페이지를 펼쳐서 마지막 페이지를 덮을 때까지, 혼자서도 충분히 파이썬을 배울 수 '
#                  '있다는 자신감과 확신이 계속될 것입니다!\n'
#                  '\n'
#                  '베타리더와 함께 입문자에게 맞는 난이도, 분량, 학습 요소 등을 적극 반영했습니다. 어려운 용어와 개념은 한 '
#                  '번 더 풀어쓰고, 복잡한 설명은 눈에 잘 들어오는 그림으로 풀어냈습니다. ‘혼자 공부해 본’ 여러 입문자의 '
#                  '초심과 눈높이가 책 곳곳에 반영된 것이 이 책의 가장 큰 장점입니다.',
#   'discount': '19800',
#   'image': 'https://shopping-phinf.pstatic.net/main_3250760/32507605957.20230509170119.jpg',
#   'isbn': '9791162245651',
#   'link': 'https://search.shopping.naver.com/book/catalog/32507605957',
#   'pubdate': '20220601',
#   'publisher': '한빛미디어',
#   'title': '혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)'},
#  {'author': '박응용',
#   'description': '프로그래밍 분야 8년 연속 베스트셀러!\n'
#                  '《Do it! 점프 투 파이썬》 전면 개정 2판 출시!\n'
#                  '\n'
#                  '중고등학생도, 비전공자도, 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개정 2판으로 새롭게 '
#                  '태어났다! 챗GPT를 시작으로 펼쳐진 생성 AI 시대에 맞춰 설명과 예제를 다듬고, 최신 경향과 심화 내용을 '
#                  '보충했다. 또한 이번 개정 2판도 50만 코딩 유튜버인 조코딩과 협업을 통해 유튜브 동영상을 제공해 파이썬을 '
#                  '더 쉽게 공부할 수 있다.\n'
#                  '\n'
#                  '8년 연속 베스트셀러! 위키독스 누적 방문 300만! 독자의 입에서 입으로 전해진 추천과 수많은 대학 및 '
#                  '학원의 교재 채택을 통해 검증은 이미 끝났다. 코딩을 처음 배우는 중고등학생부터 코딩 소양을 기르려는 '
#                  '비전공자, 자기계발에 진심인 직장인까지! 이 책과 함께 파이썬 프로그래밍의 세계로 ‘점프’해 보자!',
#   'discount': '19800',
#   'image': 'https://shopping-phinf.pstatic.net/main_4035408/40354085633.20230927071024.jpg',
#   'isbn': '9791163034735',
#   'link': 'https://search.shopping.naver.com/book/catalog/40354085633',
#   'pubdate': '20230615',
#   'publisher': '이지스퍼블리싱',
#   'title': 'Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)'},
#  {'author': '사이토 고키',
#   'description': '딥러닝 분야 부동의 베스트셀러!\n'
#                  '머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서\n'
#                  '\n'
#                  '이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수 있도록 도와주는 '
#                  '친절한 안내서입니다. 라이브러리나 프레임워크에 의존하지 않고 딥러닝의 기본 개념부터 이미지 인식에 활용되는 '
#                  '합성곱 신경망(CNN)까지 딥러닝의 원리를 체계적으로 설명합니다. 또한 복잡한 개념은 계산 그래프를 활용해 '
#                  '시각적으로 전달하여 누구나 쉽게 이해할 수 있습니다. 이 책은 딥러닝에 첫발을 내딛는 입문자는 물론이고 '
#                  '기초를 다시금 다지고 싶은 개발자와 연구자에게도 훌륭한 길잡이가 되어줄 것입니다.',
#   'discount': '23400',
#   'image': 'https://shopping-phinf.pstatic.net/main_5261555/52615553184.20250123071242.jpg',
#   'isbn': '9791169213387',
#   'link': 'https://search.shopping.naver.com/book/catalog/52615553184',
#   'pubdate': '20250124',
#   'publisher': '한빛미디어',
#   'title': '밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)'},
#  {'author': '홍의경',
#   'description': '코딩 실력을 키우는 지름길은 실습이다.\n'
#                  '\n'
#                  '2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 '
#                  '교과서가 검인정에 합격하였는데, 파이썬을 기반으로 하는 교과서가 2종류, C언어를 기반으로 하는 교과서가 '
#                  '2종류, 베이직을 기반으로 하는 교과서가 2종류, 스크래치를 기반으로 하는 교과서가 2종류였습니다.\n'
#                  '\n'
#                  '교육용 언어로 시작한 파이썬이 중학교 학생들이 비교적 쉽게 학습할 수 있는 프로그래밍 언어라고 생각했는데 '
#                  '10여년의 세월이 흐른 지금 파이썬이 활용되는 분야가 가히 폭발적으로 증가하였습니다. \n'
#                  '\n'
#                  '파이썬에 관한 쉽고 좋은 교재를 저술하기 위해서 인터넷에서 30,000페이지 이상의 자료를 찾아서 '
#                  '검토하였습니다. 어쩌면 파이썬이 첫 프로그래밍 언어일 본 교재의 독자들이 두려움 없이 파이썬을 기초부터 쉽게 '
#                  '공부하다가, 교재를 다 읽고 나면 “어느새 중급 수준에 도달했구나”라는 생각이 들도록  완성도 높은 교재를 '
#                  '목표로 하였습니다. \n'
#                  '\n'
#                  '입문자를 대상으로 하는 교재일수록 집필하는데 훨씬 더 많은 정성과 노력이 필요하다는 것을 잘 알고 있습니다. '
#                  '개인적으로는 데이터베이스 전공교재를 저술할 때보다 몇 배 더 힘들었고, 공을 많이 들였습니다. \n'
#                  '\n'
#                  '원고를 버전 9까지 작성하는 동안 셀 수 없이 원고를 읽어보면서 꼭 필요하지 않은 문장은 삭제하고, 필요한 '
#                  '문장은 반드시 넣었습니다. 고등학교 검인정 교과서 1권, 중학교 검인정 교과서 3권, 데이터베이스 전공 교재 '
#                  '2권, 엑셀 교재 1권, 번역서 2권을 집필하면서 나름대로 한글을 정확하고 간결하게 표현하는데 자신이 '
#                  '있습니다.',
#   'discount': '29440',
#   'image': 'https://shopping-phinf.pstatic.net/main_3246098/32460987987.20230207163755.jpg',
#   'isbn': '9788970506784',
#   'link': 'https://search.shopping.naver.com/book/catalog/32460987987',
#   'pubdate': '20220309',
#   'publisher': '생능출판',
#   'title': '파이썬'},
#  {'author': '김상민^장성식^김일태',
#   'description': '파이썬으로 다지는 프로그래밍의 기초\n'
#                  '\n'
#                  'ㆍ 다양한 예제를 활용하여 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 파이썬 입문서입니다.\n'
#                  'ㆍ 문법을 사전식으로 나열하지 않고 기능적인 프로그램을 하나씩 완성하면서 익힐 수 있게 구성했습니다.\n'
#                  'ㆍ 단계별로 완성하는 장별 예제 및 연습문제를 바탕으로 자신만의 프로그램을 완성할 수 있습니다.',
#   'discount': '18000',
#   'image': 'https://shopping-phinf.pstatic.net/main_3244094/32440944646.20230509164030.jpg',
#   'isbn': '9788959604210',
#   'link': 'https://search.shopping.naver.com/book/catalog/32440944646',
#   'pubdate': '20220210',
#   'publisher': '렉스미디어닷넷',
#   'title': 'CODING BASICS PYTHON (파이썬)'},
#  {'author': '염기원^오지영',
#   'description': '책의 전반부는 비전공자의 입장에서 비전공자를 위한 파이썬 프로그래밍의 기초적인 내용으로 구성되어 있다. '
#                  '프로그래밍에 익숙하거나 파이썬 경험이 있는 독자들은 곧바로 책의 후반부를 공부하는 것을 권한다. 책의 '
#                  '전반부에서는 저자가 처음 컴퓨터 프로그래밍이라는 것을 배울 때 가장 어려워했던 변수와 메모리 관계, 특성에 '
#                  '대해서 상세하게 설명하면서 비전공자들이 쉽게 프로그래밍에 입문할 수 있도록 하였다. 대부분의 프로그래밍 '
#                  '교재와 다를바 없이, 파이썬으로 프로그램을 작성할 수 있도록 개발환경을 설치하는 과정과 사용 가능한 '
#                  '프로그래밍 툴에 대해서도 빠지지 않고 최대한 상세한 설명과 충분한 그림을 삽입하였다. 또한, 전반부의 '
#                  '뒷부분은 데이터 분석에 필요한 파이썬 프로그램 위주로 구성해서 앞부분의 기초 프로그래밍 지식을 바탕으로 '
#                  '본격적인 데이터 분석을 위한 토대를 마련할 수 있도록 구성하였다.',
#   'discount': '16200',
#   'image': 'https://shopping-phinf.pstatic.net/main_3243624/32436240934.20230928092006.jpg',
#   'isbn': '9791166750991',
#   'link': 'https://search.shopping.naver.com/book/catalog/32436240934',
#   'pubdate': '20220120',
#   'publisher': '북두',
#   'title': '파이썬 (제2판)'},
#  {'author': '천인국',
#   'description': '컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 '
#                  '언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨팅 사고는 복잡한 문제를 분해하여 '
#                  '문제 안에 내재된 패턴을 찾고 추상화 단계를 거쳐서 문제를 해결하는 알고리즘을 작성하는 과정이다. 작성된 '
#                  '알고리즘은 사람이 수행하거나 컴퓨터를 이용하여 자동화될 수 있다. \n'
#                  '이 책은 컴퓨팅 사고와 파이썬을 동시에 학습할 수 있도록 기획되었다. 파이썬은 컴퓨터를 전공하지 않은 '
#                  '학생들도 쉽게 사용할 수 있다는 큰 장점이 있다. 컴퓨팅 사고는 흥미로운 실습 예제가 많이 필요하다. 이 '
#                  '책에서는 최대한 많은 실습 예제를 간추려서 파이썬으로 실습할 수 있도록 하였다. 파이썬은 다양한 '
#                  '애니메이션이나 가상 실습을 만들 수 있는 최적의 도구이다. 학생들은 파이썬을 통하여 컴퓨터 프로그래밍의 '
#                  '기본적인 개념들과 컴퓨팅 사고에서 나타나는 다양한 실습을 수행할 수 있을 것이다.',
#   'discount': '12000',
#   'image': 'https://shopping-phinf.pstatic.net/main_3248915/32489150082.20230207165503.jpg',
#   'isbn': '9791185578330',
#   'link': 'https://search.shopping.naver.com/book/catalog/32489150082',
#   'pubdate': '20170830',
#   'publisher': '인피니티북스',
#   'title': '파이썬'},
#  {'author': '김명호',
#   'description': '막막했던 파이썬, 이제 한 권으로 기초를 배우는\n'
#                  '파이썬 사용 설명서!\n'
#                  '\n'
#                  '전 세계적으로 유명한 구글(Google)이 자신의 많은 서비스를 파이썬으로 제공하고 있습니다. 이것은 구글의 '
#                  '뛰어난 서비스를 개인의 비즈니스에 쉽게 이용할 수 있다는 의미입니다.  이러한 발전에 맞춰 파이썬 문법의 '
#                  '기초를 쉽게 이해할 수 있도록 이 책에서는 친절한 도해와 함께 코딩 개념을 설명합니다. 파이썬을 처음 배우는 '
#                  '학생부터 비전공자, 코딩 실력을 높이려는 직장인까지 기본 문법부터 예제를 통한 활용 실력을 높여 파이썬 '
#                  '프로그래밍을 마스터할 수 있습니다. 가장 쉽고, 빠르게, 효율적인 파이썬 사용 설명서! ‘한 권으로 끝내는 '
#                  '파이썬’에서 찾아보세요.',
#   'discount': '16200',
#   'image': 'https://shopping-phinf.pstatic.net/main_3243600/32436003648.20230920072841.jpg',
#   'isbn': '9791186179369',
#   'link': 'https://search.shopping.naver.com/book/catalog/32436003648',
#   'pubdate': '20190525',
#   'publisher': '에듀웨이',
#   'title': '파이썬 (비전공자를위한 파이썬 기초 입문서)'},
#  {'author': '염기원',
#   'description': '비전공자의 데이터 분석을 위한 『파이썬』은 〈파이썬 기초〉, 〈파이썬을 이용한 데이터 분석 기초〉, 〈시각화 '
#                  '라이브러리 사용하기〉 등 파이썬의 기초적이고 전반적인 내용이 수록되어 있다.',
#   'discount': '0',
#   'image': 'https://shopping-phinf.pstatic.net/main_3249027/32490271648.20220527033830.jpg',
#   'isbn': '9791159069048',
#   'link': 'https://search.shopping.naver.com/book/catalog/32490271648',
#   'pubdate': '20200820',
#   'publisher': '복두출판사',
#   'title': '파이썬'}]

# %%
print("\n=== 추천 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    price = int(book.get('discount',0))  # price 없으면 0 처리
    pubdate = book.get('pubdate', '')
    pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:]}"

    print(f"\n{idx}. {book['title']}")
    print(f"   저자: {book['author']}")
    print(f"   출판사: {book['publisher']}")
    print(f"   출판일: {pubdate}")
    print(f"   가격: {price:,}원")
    print(f"   설명: {book['description'][:100]}...")  # 100자만 출력
# Out:
# === 추천 도서 목록 ===
#
# 1. 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
#    저자: 문현일
#    출판사: 한빛미디어
#    출판일: 2025-02-14
#    가격: 23,400원
#    설명: “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”
# 나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등
# 생활 속  15가지 파이썬 프...
#
# 2. 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
#    저자: 윤인성
#    출판사: 한빛미디어
#    출판일: 2022-06-01
#    가격: 19,800원
#    설명: 혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서
#
# 『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따...
#
# 3. Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
#    저자: 박응용
#    출판사: 이지스퍼블리싱
#    출판일: 2023-06-15
#    가격: 19,800원
#    설명: 프로그래밍 분야 8년 연속 베스트셀러!
# 《Do it! 점프 투 파이썬》 전면 개정 2판 출시!
#
# 중고등학생도, 비전공자도, 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개...
#
# 4. 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
#    저자: 사이토 고키
#    출판사: 한빛미디어
#    출판일: 2025-01-24
#    가격: 23,400원
#    설명: 딥러닝 분야 부동의 베스트셀러!
# 머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서
#
# 이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수...
#
# 5. 파이썬
#    저자: 홍의경
#    출판사: 생능출판
#    출판일: 2022-03-09
#    가격: 29,440원
#    설명: 코딩 실력을 키우는 지름길은 실습이다.
#
# 2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 교과서가 검인정에 합격하였는데...
#
# 6. CODING BASICS PYTHON (파이썬)
#    저자: 김상민^장성식^김일태
#    출판사: 렉스미디어닷넷
#    출판일: 2022-02-10
#    가격: 18,000원
#    설명: 파이썬으로 다지는 프로그래밍의 기초
#
# ㆍ 다양한 예제를 활용하여 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 파이썬 입문서입니다.
# ㆍ 문법을 사전식으로 나열하지 않고 기능적인 ...
#
# 7. 파이썬 (제2판)
#    저자: 염기원^오지영
#    출판사: 북두
#    출판일: 2022-01-20
#    가격: 16,200원
#    설명: 책의 전반부는 비전공자의 입장에서 비전공자를 위한 파이썬 프로그래밍의 기초적인 내용으로 구성되어 있다. 프로그래밍에 익숙하거나 파이썬 경험이 있는 독자들은 곧바로 책의 후반부를 공...
#
# 8. 파이썬
#    저자: 천인국
#    출판사: 인피니티북스
#    출판일: 2017-08-30
#    가격: 12,000원
#    설명: 컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨...
#
# 9. 파이썬 (비전공자를위한 파이썬 기초 입문서)
#    저자: 김명호
#    출판사: 에듀웨이
#    출판일: 2019-05-25
#    가격: 16,200원
#    설명: 막막했던 파이썬, 이제 한 권으로 기초를 배우는
# 파이썬 사용 설명서!
#
# 전 세계적으로 유명한 구글(Google)이 자신의 많은 서비스를 파이썬으로 제공하고 있습니다. 이것은 구글의...
#
# 10. 파이썬
#    저자: 염기원
#    출판사: 복두출판사
#    출판일: 2020-08-20
#    가격: 0원
#    설명: 비전공자의 데이터 분석을 위한 『파이썬』은 〈파이썬 기초〉, 〈파이썬을 이용한 데이터 분석 기초〉, 〈시각화 라이브러리 사용하기〉 등 파이썬의 기초적이고 전반적인 내용이 수록되어 ...

# %%
print("\n=== 인피니티북스 출판 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    if '인피니티북스' in book['publisher']:
        price = int(book.get('discount', 0))
        pubdate = book.get('pubdate', '')
        if len(pubdate) == 8:
            pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:]}"
        else:
            pubdate = "출판일 정보 없음"

        print(f"\n{idx}. {book['title']}")
        print(f"   저자: {book['author']}")
        print(f"   출판사: {book['publisher']}")
        print(f"   출판일: {pubdate}")
        print(f"   가격: {price:,}원")
        print(f"   설명: {book['description'][:100]}...")
# Out:
# === 인피니티북스 출판 도서 목록 ===
#
# 8. 파이썬
#    저자: 천인국
#    출판사: 인피니티북스
#    출판일: 2017-08-30
#    가격: 12,000원
#    설명: 컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨...

# %%
print("\n=== 가격이 20,000원 이상인 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    price = int(book.get('discount', 0))
    if price >= 20000:
        pubdate = book.get('pubdate', '')
        if len(pubdate) == 8:
            pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:]}"
        else:
            pubdate = "출판일 정보 없음"

        print(f"\n{idx}. {book['title']}")
        print(f"   저자: {book['author']}")
        print(f"   출판사: {book['publisher']}")
        print(f"   출판일: {pubdate}")
        print(f"   가격: {price:,}원")
        print(f"   설명: {book['description'][:100]}...")
# Out:
# === 가격이 20,000원 이상인 도서 목록 ===
#
# 1. 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
#    저자: 문현일
#    출판사: 한빛미디어
#    출판일: 2025-02-14
#    가격: 23,400원
#    설명: “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”
# 나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등
# 생활 속  15가지 파이썬 프...
#
# 4. 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
#    저자: 사이토 고키
#    출판사: 한빛미디어
#    출판일: 2025-01-24
#    가격: 23,400원
#    설명: 딥러닝 분야 부동의 베스트셀러!
# 머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서
#
# 이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수...
#
# 5. 파이썬
#    저자: 홍의경
#    출판사: 생능출판
#    출판일: 2022-03-09
#    가격: 29,440원
#    설명: 코딩 실력을 키우는 지름길은 실습이다.
#
# 2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 교과서가 검인정에 합격하였는데...

# %%
print("\n=== JSON 파일로 저장 ===")

import json

with open('../data/python_books.json', 'w', encoding='utf-8') as f:
    json.dump(items_data, f, ensure_ascii=False, indent=2)
    
print("JSON 저장 완료!")
# Out:
# === JSON 파일로 저장 ===
# JSON 저장 완료!

# %%
def print_book(idx, book):
    price = int(book.get('discount', 0))
    pubdate = book.get('pubdate', '')
    pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:]}" if len(pubdate) == 8 else "출판일 정보 없음"

    print(f"\n{idx}. {book['title']}")
    print(f"   저자: {book['author']}")
    print(f"   출판사: {book['publisher']}")
    print(f"   출판일: {pubdate}")
    print(f"   가격: {price:,}원")
    print(f"   설명: {book['description'][:100]}...")

# %%
print("\n=== 추천 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    print_book(idx, book)
# Out:
# === 추천 도서 목록 ===
#
# 1. 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
#    저자: 문현일
#    출판사: 한빛미디어
#    출판일: 2025-02-14
#    가격: 23,400원
#    설명: “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”
# 나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등
# 생활 속  15가지 파이썬 프...
#
# 2. 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
#    저자: 윤인성
#    출판사: 한빛미디어
#    출판일: 2022-06-01
#    가격: 19,800원
#    설명: 혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서
#
# 『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따...
#
# 3. Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
#    저자: 박응용
#    출판사: 이지스퍼블리싱
#    출판일: 2023-06-15
#    가격: 19,800원
#    설명: 프로그래밍 분야 8년 연속 베스트셀러!
# 《Do it! 점프 투 파이썬》 전면 개정 2판 출시!
#
# 중고등학생도, 비전공자도, 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개...
#
# 4. 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
#    저자: 사이토 고키
#    출판사: 한빛미디어
#    출판일: 2025-01-24
#    가격: 23,400원
#    설명: 딥러닝 분야 부동의 베스트셀러!
# 머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서
#
# 이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수...
#
# 5. 파이썬
#    저자: 홍의경
#    출판사: 생능출판
#    출판일: 2022-03-09
#    가격: 29,440원
#    설명: 코딩 실력을 키우는 지름길은 실습이다.
#
# 2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 교과서가 검인정에 합격하였는데...
#
# 6. CODING BASICS PYTHON (파이썬)
#    저자: 김상민^장성식^김일태
#    출판사: 렉스미디어닷넷
#    출판일: 2022-02-10
#    가격: 18,000원
#    설명: 파이썬으로 다지는 프로그래밍의 기초
#
# ㆍ 다양한 예제를 활용하여 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 파이썬 입문서입니다.
# ㆍ 문법을 사전식으로 나열하지 않고 기능적인 ...
#
# 7. 파이썬 (제2판)
#    저자: 염기원^오지영
#    출판사: 북두
#    출판일: 2022-01-20
#    가격: 16,200원
#    설명: 책의 전반부는 비전공자의 입장에서 비전공자를 위한 파이썬 프로그래밍의 기초적인 내용으로 구성되어 있다. 프로그래밍에 익숙하거나 파이썬 경험이 있는 독자들은 곧바로 책의 후반부를 공...
#
# 8. 파이썬
#    저자: 천인국
#    출판사: 인피니티북스
#    출판일: 2017-08-30
#    가격: 12,000원
#    설명: 컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨...
#
# 9. 파이썬 (비전공자를위한 파이썬 기초 입문서)
#    저자: 김명호
#    출판사: 에듀웨이
#    출판일: 2019-05-25
#    가격: 16,200원
#    설명: 막막했던 파이썬, 이제 한 권으로 기초를 배우는
# 파이썬 사용 설명서!
#
# 전 세계적으로 유명한 구글(Google)이 자신의 많은 서비스를 파이썬으로 제공하고 있습니다. 이것은 구글의...
#
# 10. 파이썬
#    저자: 염기원
#    출판사: 복두출판사
#    출판일: 2020-08-20
#    가격: 0원
#    설명: 비전공자의 데이터 분석을 위한 『파이썬』은 〈파이썬 기초〉, 〈파이썬을 이용한 데이터 분석 기초〉, 〈시각화 라이브러리 사용하기〉 등 파이썬의 기초적이고 전반적인 내용이 수록되어 ...

# %%
print("\n=== 한빛미디어 출판 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    if '한빛미디어' in book['publisher']:
        print_book(idx, book)
# Out:
# === 한빛미디어 출판 도서 목록 ===
#
# 1. 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
#    저자: 문현일
#    출판사: 한빛미디어
#    출판일: 2025-02-14
#    가격: 23,400원
#    설명: “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”
# 나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등
# 생활 속  15가지 파이썬 프...
#
# 2. 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
#    저자: 윤인성
#    출판사: 한빛미디어
#    출판일: 2022-06-01
#    가격: 19,800원
#    설명: 혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서
#
# 『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따...
#
# 4. 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
#    저자: 사이토 고키
#    출판사: 한빛미디어
#    출판일: 2025-01-24
#    가격: 23,400원
#    설명: 딥러닝 분야 부동의 베스트셀러!
# 머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서
#
# 이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수...

# %%
print("\n=== 가격이 20,000원 이하인 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    price = int(book.get('discount', 0))
    if price <= 20000:
        print_book(idx, book)
# Out:
# === 가격이 20,000원 이하인 도서 목록 ===
#
# 2. 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
#    저자: 윤인성
#    출판사: 한빛미디어
#    출판일: 2022-06-01
#    가격: 19,800원
#    설명: 혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서
#
# 『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따...
#
# 3. Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
#    저자: 박응용
#    출판사: 이지스퍼블리싱
#    출판일: 2023-06-15
#    가격: 19,800원
#    설명: 프로그래밍 분야 8년 연속 베스트셀러!
# 《Do it! 점프 투 파이썬》 전면 개정 2판 출시!
#
# 중고등학생도, 비전공자도, 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개...
#
# 6. CODING BASICS PYTHON (파이썬)
#    저자: 김상민^장성식^김일태
#    출판사: 렉스미디어닷넷
#    출판일: 2022-02-10
#    가격: 18,000원
#    설명: 파이썬으로 다지는 프로그래밍의 기초
#
# ㆍ 다양한 예제를 활용하여 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 파이썬 입문서입니다.
# ㆍ 문법을 사전식으로 나열하지 않고 기능적인 ...
#
# 7. 파이썬 (제2판)
#    저자: 염기원^오지영
#    출판사: 북두
#    출판일: 2022-01-20
#    가격: 16,200원
#    설명: 책의 전반부는 비전공자의 입장에서 비전공자를 위한 파이썬 프로그래밍의 기초적인 내용으로 구성되어 있다. 프로그래밍에 익숙하거나 파이썬 경험이 있는 독자들은 곧바로 책의 후반부를 공...
#
# 8. 파이썬
#    저자: 천인국
#    출판사: 인피니티북스
#    출판일: 2017-08-30
#    가격: 12,000원
#    설명: 컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨...
#
# 9. 파이썬 (비전공자를위한 파이썬 기초 입문서)
#    저자: 김명호
#    출판사: 에듀웨이
#    출판일: 2019-05-25
#    가격: 16,200원
#    설명: 막막했던 파이썬, 이제 한 권으로 기초를 배우는
# 파이썬 사용 설명서!
#
# 전 세계적으로 유명한 구글(Google)이 자신의 많은 서비스를 파이썬으로 제공하고 있습니다. 이것은 구글의...
#
# 10. 파이썬
#    저자: 염기원
#    출판사: 복두출판사
#    출판일: 2020-08-20
#    가격: 0원
#    설명: 비전공자의 데이터 분석을 위한 『파이썬』은 〈파이썬 기초〉, 〈파이썬을 이용한 데이터 분석 기초〉, 〈시각화 라이브러리 사용하기〉 등 파이썬의 기초적이고 전반적인 내용이 수록되어 ...

# %%
import requests
import os
from dotenv import load_dotenv
from pprint import pprint

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret,
}

# query string 문자열을 dict 선언
payload = {
    'query': '가디건',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/shop.json' #?query=파이썬&display=100&sort=sim

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기
items_data = res.json()['items']

pprint(items_data)
# Out:
# [{'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8421665/84216650390.13.jpg',
#   'link': 'https://smartstore.naver.com/main/products/6672150068',
#   'lprice': '64900',
#   'maker': '폴로랄프로렌',
#   'mallName': '나우인뉴욕',
#   'productId': '84216650390',
#   'productType': '2',
#   'title': '백화점3-5일배송 폴로 <b>가디건</b> 걸즈 걸스 랄프로렌 꽈배기 블랙 화이트 핑크 헌터네이비XL'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8301144/83011442056.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5466947569',
#   'lprice': '19900',
#   'maker': '',
#   'mallName': 'ARUMY',
#   'productId': '83011442056',
#   'productType': '2',
#   'title': '봄 가을 간절기 라운드 루즈핏 크롭 <b>가디건</b> 레드 그린 핑크 화이트 블랙 옐로우'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8599496/85994962324.3.jpg',
#   'link': 'https://smartstore.naver.com/main/products/8450462001',
#   'lprice': '63900',
#   'maker': '폴로랄프로렌',
#   'mallName': '트위티 155',
#   'productId': '85994962324',
#   'productType': '2',
#   'title': '[백화점3-5일배송] 폴로 <b>가디건</b> 니트 걸즈 랄프로렌 블랙 화이트 핑크 헌터네이비XL L'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8237267/82372678315.3.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4828155463',
#   'lprice': '18900',
#   'maker': '',
#   'mallName': '코이블리',
#   'productId': '82372678315',
#   'productType': '2',
#   'title': '부드러운 캐시미어 크롭 <b>가디건</b> 숏 라운드 니트<b>가디건</b> 여성 <b>가디건</b> 봄 간절기 레드 '
#            '핑크'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8865189/88651894622.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/11107384300',
#   'lprice': '69000',
#   'maker': '폴로랄프로렌',
#   'mallName': '세컨찬스라이프',
#   'productId': '88651894622',
#   'productType': '2',
#   'title': '[백화점] 폴로 <b>가디건</b> 걸즈 케이블 꽈배기 니트'},
#  {'brand': '꼼데가르송',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8228612/82286128596.6.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4741606965',
#   'lprice': '254390',
#   'maker': '',
#   'mallName': '레이바쿠',
#   'productId': '82286128596',
#   'productType': '2',
#   'title': '꼼데가르송 기본와펜 <b>가디건</b> 여성용'},
#  {'brand': '메종키츠네',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8284715/82847151528.5.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5302659122',
#   'lprice': '267000',
#   'maker': '메종키츠네',
#   'mallName': '브랜드리퍼블릭',
#   'productId': '82847151528',
#   'productType': '2',
#   'title': '메종키츠네 <b>가디건</b> 베이비폭스 폭스헤드 더블폭스 칠랙스 [당일출고]'},
#  {'brand': '폴로',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8097217/80972174298.23.jpg',
#   'link': 'https://smartstore.naver.com/main/products/3427657202',
#   'lprice': '209000',
#   'maker': '폴로',
#   'mallName': '바이찬스',
#   'productId': '80972174298',
#   'productType': '2',
#   'title': '(8컬러)폴로랄프로렌 피마코튼 여성 <b>가디건</b>'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8331054/83310547814.5.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5766048400',
#   'lprice': '59900',
#   'maker': '폴로랄프로렌',
#   'mallName': '뉴욕바잉',
#   'productId': '83310547814',
#   'productType': '2',
#   'title': '[미국 백화점] 폴로 <b>가디건</b> 걸스 걸즈 랄프로렌 꽈배기 케이블 니트 <b>가디건</b> 네이비 블랙 핑크 '
#            '화이트 L XL'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8751613/87516136471.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9971634198',
#   'lprice': '49500',
#   'maker': '',
#   'mallName': '루나드엘',
#   'productId': '87516136471',
#   'productType': '2',
#   'title': '드온도 노튼 캐시미어 <b>가디건</b> 봄 스프링 라운드 니트 deondo'},
#  {'brand': '제너럴아이디어',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5328720/53287208769.20250302141747.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/53287208769',
#   'lprice': '32400',
#   'maker': '제너럴아이디어',
#   'mallName': '네이버',
#   'productId': '53287208769',
#   'productType': '1',
#   'title': '제너럴아이디어 WOMAN GNRL 에센셜 베이직 <b>카디건</b> 11COL WBD3L04503'},
#  {'brand': 'H&M',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5178161/51781610172.20241205202656.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/51781610172',
#   'lprice': '17512',
#   'maker': 'H&M',
#   'mallName': '네이버',
#   'productId': '51781610172',
#   'productType': '1',
#   'title': 'H&amp;M HM 파인 니트 <b>가디건</b> 0579541001'},
#  {'brand': '폴로랄프로렌',
#   'category1': '출산/육아',
#   'category2': '유아동의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8700404/87004045841.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9459545518',
#   'lprice': '69000',
#   'maker': '폴로랄프로렌',
#   'mallName': '리틀데이즈',
#   'productId': '87004045841',
#   'productType': '2',
#   'title': '[국내발송 + 선물포장] 폴로 랄프로렌 여아 아기 코튼 베이비 <b>가디건</b> 핑크 옐로우 화이트'},
#  {'brand': '꼼데가르송',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8548983/85489838433.6.jpg',
#   'link': 'https://smartstore.naver.com/main/products/7945338110',
#   'lprice': '315800',
#   'maker': '꼼데가르송',
#   'mallName': '브랜드사는이쁜언니',
#   'productId': '85489838433',
#   'productType': '2',
#   'title': '[국내배송] 꼼데가르송 <b>가디건</b> 기본와펜 여성/남성용'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8760912/87609120854.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/10064618231',
#   'lprice': '29800',
#   'maker': '',
#   'mallName': '미드시티 여성니트',
#   'productId': '87609120854',
#   'productType': '2',
#   'title': '레이어드<b>가디건</b> 캐시미어<b>가디건</b> 여자봄<b>가디건</b> 사무실'},
#  {'brand': '라코스테',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4971414/49714141886.20240827160222.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/49714141886',
#   'lprice': '80100',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '49714141886',
#   'productType': '1',
#   'title': '라코스테 남성 베이직 V넥 방모 <b>가디건</b> AH560E-54N'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8658938/86589381117.3.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9044880794',
#   'lprice': '42000',
#   'maker': '',
#   'mallName': 'ttoyuni',
#   'productId': '86589381117',
#   'productType': '2',
#   'title': '(당일) 프리티영띵 뉴 페블 골지 <b>가디건</b> PYT 프영띵 떠유니'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8293607/82936073452.3.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5391580059',
#   'lprice': '29900',
#   'maker': '',
#   'mallName': '지읒이응',
#   'productId': '82936073452',
#   'productType': '2',
#   'title': '여자 보풀없는 캐시미어 비스코스 니트 여성 라운드 <b>가디건</b> 인디핑크 병원 간호 사무실'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8417400/84174006523.jpg',
#   'link': 'https://smartstore.naver.com/main/products/6629506201',
#   'lprice': '115000',
#   'maker': '폴로랄프로렌',
#   'mallName': '트렌드홀릭',
#   'productId': '84174006523',
#   'productType': '2',
#   'title': '[우체국당일발송] 폴로 걸즈 <b>가디건</b> XL / 폴로 랄프로렌 걸즈 케이블 니트 꽈배기 <b>가디건</b>'},
#  {'brand': '톰브라운',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8411081/84110815544.4.jpg',
#   'link': 'https://smartstore.naver.com/main/products/6566315211',
#   'lprice': '809000',
#   'maker': '톰브라운',
#   'mallName': '버닝웨어',
#   'productId': '84110815544',
#   'productType': '2',
#   'title': '톰브라운 <b>가디건</b> 울 밀라노 스티치 MKC002A'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8313657/83136576950.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5592080655',
#   'lprice': '23900',
#   'maker': '',
#   'mallName': '고고하니',
#   'productId': '83136576950',
#   'productType': '2',
#   'title': '시스루 얇은 린넨 루즈핏 니트 여름 여성 <b>가디건</b> (올타임)'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8552937/85529371107.jpg',
#   'link': 'https://smartstore.naver.com/main/products/7984870784',
#   'lprice': '27000',
#   'maker': '',
#   'mallName': '건강한생활82',
#   'productId': '85529371107',
#   'productType': '2',
#   'title': '티블러썸 결혼식 하객룩 진주단추 <b>가디건</b> 봄 퍼프 니트 여성 금장 크롭 <b>가디건</b> 6color'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8273930/82739301366.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5194780033',
#   'lprice': '24800',
#   'maker': '',
#   'mallName': '베이지블랑.',
#   'productId': '82739301366',
#   'productType': '2',
#   'title': '포인즈 부드럽고 포근해 얇은 니트 울 오버핏 <b>가디건</b> 여성 <b>가디건</b> 겨울 봄'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8750404/87504043024.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9959540751',
#   'lprice': '24900',
#   'maker': '',
#   'mallName': 'ARUMY',
#   'productId': '87504043024',
#   'productType': '2',
#   'title': '10COLOR 여성 봄 비비드컬러 라운드 슬릿넥 크롭 니트 그린 핑크<b>가디건</b>'},
#  {'brand': '사색',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8887781/88877819725.jpg',
#   'link': 'https://smartstore.naver.com/main/products/11333309394',
#   'lprice': '43700',
#   'maker': '',
#   'mallName': '사색',
#   'productId': '88877819725',
#   'productType': '2',
#   'title': '예가체프 R 파인울 <b>가디건</b>'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8876688/88766883178.3.jpg',
#   'link': 'https://smartstore.naver.com/main/products/11222372847',
#   'lprice': '68700',
#   'maker': '폴로랄프로렌',
#   'mallName': '부스더샵',
#   'productId': '88766883178',
#   'productType': '2',
#   'title': '[QR인증백화점] 폴로 <b>가디건</b> 걸즈 여성 케이블 꽈배기 니트'},
#  {'brand': '벤시몽',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5323276/53232763110.20250226185010.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/53232763110',
#   'lprice': '44910',
#   'maker': '벤시몽',
#   'mallName': '네이버',
#   'productId': '53232763110',
#   'productType': '1',
#   'title': '벤시몽 여성 코튼 블렌드 케이블 <b>가디건</b> 3종'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8283547/82835473460.11.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5290981221',
#   'lprice': '39800',
#   'maker': '',
#   'mallName': '왓위웨어',
#   'productId': '82835473460',
#   'productType': '2',
#   'title': '남자<b>가디건</b> 울 라운드 캐시미어 오버핏 하찌 니트 커플<b>가디건</b> 봄 가을'},
#  {'brand': '리스트',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5114373/51143733510.20241103013933.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/51143733510',
#   'lprice': '23000',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '51143733510',
#   'productType': '1',
#   'title': '리스트 라운드넥 버튼 니트 <b>가디건</b> TSKCDO72010'},
#  {'brand': '제너럴아이디어',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4954149/49541497760.20250211235224.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/49541497760',
#   'lprice': '31416',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '49541497760',
#   'productType': '1',
#   'title': '제너럴아이디어 GENERALIDEA WOMAN 에센셜 크루넥 <b>가디건</b> 4COL WBD3L04501'},
#  {'brand': '비비안웨스트우드',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4347513/43475137325.20240409151632.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/43475137325',
#   'lprice': '28070',
#   'maker': '비비안웨스트우드',
#   'mallName': '네이버',
#   'productId': '43475137325',
#   'productType': '1',
#   'title': '비비안웨스트우드 여성 베아 울 실크 <b>가디건</b> 1803001Z'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8672484/86724841798.5.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9180341475',
#   'lprice': '129000',
#   'maker': '폴로랄프로렌',
#   'mallName': '포니홀릭',
#   'productId': '86724841798',
#   'productType': '2',
#   'title': '폴로 랄프로렌 케이블 <b>가디건</b> 보이즈 (3컬러)'},
#  {'brand': '꼼데가르송',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8227212/82272120255.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4727598933',
#   'lprice': '254300',
#   'maker': '꼼데가르송',
#   'mallName': '레이바쿠',
#   'productId': '82272120255',
#   'productType': '2',
#   'title': '꼼데가르송 기본와펜 <b>가디건</b> 남성용'},
#  {'brand': '꼼데가르송',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8346903/83469038520.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5924539032',
#   'lprice': '329000',
#   'maker': '꼼데가르송',
#   'mallName': '도쿄루꼬',
#   'productId': '83469038520',
#   'productType': '2',
#   'title': '꼼데가르송 꼼데 <b>가디건</b> 여성 남성 니트'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8664218/86642182308.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9097681985',
#   'lprice': '159000',
#   'maker': '',
#   'mallName': '포니홀릭',
#   'productId': '86642182308',
#   'productType': '2',
#   'title': '[백화점] 폴로 랄프로렌 남자 코튼 브이넥 <b>가디건</b> (4컬러)'},
#  {'brand': '',
#   'category1': '출산/육아',
#   'category2': '유아동의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8244637/82446374164.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4901850589',
#   'lprice': '19800',
#   'maker': '',
#   'mallName': '로이앤한나',
#   'productId': '82446374164',
#   'productType': '2',
#   'title': '카렌 여름 가을 간절기 여자 아기<b>가디건</b> 유아<b>가디건</b> 3개월 6개월 9개월 돌아기'},
#  {'brand': '메종키츠네',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8243806/82438065670.9.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4893542136',
#   'lprice': '259000',
#   'maker': '메종키츠네',
#   'mallName': '브랜드리퍼블릭',
#   'productId': '82438065670',
#   'productType': '2',
#   'title': '메종키츠네 <b>가디건</b> 폭스헤드 트리컬러 베이비폭스 볼드폭스'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8192696/81926962185.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4382440024',
#   'lprice': '18900',
#   'maker': '',
#   'mallName': '코이블리',
#   'productId': '81926962185',
#   'productType': '2',
#   'title': '루즈핏 캐시미어 브이넥<b>가디건</b> 숏 크롭 여성<b>가디건</b> 니트<b>가디건</b> 봄 간절기 레드 핑크 '
#            '블랙'},
#  {'brand': '사색',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8905979/89059794147.jpg',
#   'link': 'https://smartstore.naver.com/main/products/11515283775',
#   'lprice': '39700',
#   'maker': '',
#   'mallName': '사색',
#   'productId': '89059794147',
#   'productType': '2',
#   'title': '허브 R 크롭트 <b>가디건</b>'},
#  {'brand': '라코스테',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4991275/49912758699.20241007123301.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/49912758699',
#   'lprice': '143100',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '49912758699',
#   'productType': '1',
#   'title': '라코스테 여성 케이블 크루넥 <b>가디건</b> AF091E-54N'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5369025/53690259105.20250321193714.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/53690259105',
#   'lprice': '13100',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '53690259105',
#   'productType': '1',
#   'title': 'LE TROIS 23FW 르투아 투웨이 니트 집업 카라 <b>가디건</b> 2종 세트'},
#  {'brand': '비비안웨스트우드',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8380505/83805058987.6.jpg',
#   'link': 'https://smartstore.naver.com/main/products/6260556498',
#   'lprice': '261000',
#   'maker': '비비안웨스트우드',
#   'mallName': '브랜드리퍼블릭',
#   'productId': '83805058987',
#   'productType': '2',
#   'title': '비비안웨스트우드 <b>가디건</b> 여성 화이트라벨 선물패키지'},
#  {'brand': '리스트',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4958087/49580876217.20241024041635.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/49580876217',
#   'lprice': '24940',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '49580876217',
#   'productType': '1',
#   'title': '리스트 라운드넥 루즈핏 <b>가디건</b> TSKCDO72520'},
#  {'brand': '벤시몽',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5337369/53373694627.20250315071223.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/53373694627',
#   'lprice': '37650',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '53373694627',
#   'productType': '1',
#   'title': '벤시몽 여성 케이블 니트 <b>가디건</b> 3종'},
#  {'brand': '쉬즈미스',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4962546/49625464649.20241026105733.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/49625464649',
#   'lprice': '36910',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '49625464649',
#   'productType': '1',
#   'title': '쉬즈미스 메탈 라운드넥 니트 <b>가디건</b> SSKCDO31060'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5312696/53126962083.20250220205427.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/53126962083',
#   'lprice': '85980',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '53126962083',
#   'productType': '1',
#   'title': '베네통스포츠 베네통스포츠 여성 니트 <b>가디건</b> 2종'},
#  {'brand': '꼼데가르송',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8191253/81912533349.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4368011188',
#   'lprice': '292800',
#   'maker': '꼼데가르송',
#   'mallName': '레이바쿠',
#   'productId': '81912533349',
#   'productType': '2',
#   'title': '꼼데가르송 화이트와펜 <b>가디건</b> 여성용'},
#  {'brand': '로엠',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5267572/52675721484.20250215222322.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52675721484',
#   'lprice': '44910',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52675721484',
#   'productType': '1',
#   'title': '로엠 브이넥 <b>가디건</b> RMCKF23R98'},
#  {'brand': '타미힐피거',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8601657/86016577168.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/8472076845',
#   'lprice': '69000',
#   'maker': '타미힐피거',
#   'mallName': '빨간단풍 구매대행',
#   'productId': '86016577168',
#   'productType': '2',
#   'title': '타미힐피거 <b>가디건</b> 여자 베이직 코튼 비스코스 라운드넥 니트 티셔츠'},
#  {'brand': '라코스테',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5070595/50705955349.20241022102118.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/50705955349',
#   'lprice': '174090',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '50705955349',
#   'productType': '1',
#   'title': '라코스테 남성 피케 조직 V넥 울<b>가디건</b> AH697E-54N'},
#  {'brand': '메종키츠네',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8284278/82842787416.6.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5298295067',
#   'lprice': '298000',
#   'maker': '메종키츠네',
#   'mallName': '버닝웨어',
#   'productId': '82842787416',
#   'productType': '2',
#   'title': '메종키츠네 <b>가디건</b> 폭스헤드 더블폭스 베이비폭스'},
#  {'brand': '톰브라운',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5210177/52101774528.20250218073648.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52101774528',
#   'lprice': '671030',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52101774528',
#   'productType': '1',
#   'title': '톰브라운 남성 <b>가디건</b> 415 MJT167A 00535'},
#  {'brand': '타미힐피거',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8699859/86998599609.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9454099287',
#   'lprice': '65900',
#   'maker': '타미힐피거',
#   'mallName': '나우인뉴욕',
#   'productId': '86998599609',
#   'productType': '2',
#   'title': '[백화점당일출고] 타미 힐피거 남성 풀 집업 코튼 니트 남자 <b>가디건</b>'},
#  {'brand': '제너럴아이디어',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5238429/52384299518.20250225093922.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52384299518',
#   'lprice': '32472',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52384299518',
#   'productType': '1',
#   'title': '제너럴아이디어 제너럴 아이디어 WOMAN 멀티 스트라이프 크루넥 <b>가디건</b> 남색 NA WBE1L04504NA'},
#  {'brand': '리스트',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5169062/51690622371.20241204095944.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/51690622371',
#   'lprice': '24020',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '51690622371',
#   'productType': '1',
#   'title': '리스트 리스트 아웃 포켓 크롭 <b>가디건</b> TSKCDO70030'},
#  {'brand': '폴햄',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5196432/51964323969.20250402152939.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/51964323969',
#   'lprice': '28380',
#   'maker': '에이션패션',
#   'mallName': '네이버',
#   'productId': '51964323969',
#   'productType': '1',
#   'title': '폴햄 여성 자켓형 <b>가디건</b> PHF1EC2030'},
#  {'brand': '미쏘',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4944129/49441291447.20240727175400.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/49441291447',
#   'lprice': '11690',
#   'maker': '이랜드',
#   'mallName': '네이버',
#   'productId': '49441291447',
#   'productType': '1',
#   'title': '미쏘 에센셜 브이넥 베이직 <b>가디건</b> MIWCKE920T'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4572373/45723735727.20240209095302.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/45723735727',
#   'lprice': '125400',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '45723735727',
#   'productType': '1',
#   'title': '폴로랄프로렌 폴로 랄프로렌 여성 코튼 블렌드 <b>가디건</b>'},
#  {'brand': '제이슨우',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5248210/52482107751.20250114135421.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52482107751',
#   'lprice': '74310',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52482107751',
#   'productType': '1',
#   'title': '제이슨우 Spring <b>가디건</b> 3종'},
#  {'brand': '유니클로',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8760552/87605523696.jpg',
#   'link': 'https://smartstore.naver.com/main/products/10061021121',
#   'lprice': '49800',
#   'maker': '유니클로',
#   'mallName': '더헤르츠',
#   'productId': '87605523696',
#   'productType': '2',
#   'title': '유니클로 UV PROTECTION 크루넥 여성 <b>가디건</b> 자외선차단 봄 간절기 빅사이즈'},
#  {'brand': '아미',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5093174/50931741210.20250324075314.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/50931741210',
#   'lprice': '279000',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '50931741210',
#   'productType': '1',
#   'title': '아미 AMI 스몰 하트 남성 울 <b>가디건</b> 491 HKC001 001'},
#  {'brand': '셀렙샵에디션',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5302086/53020866519.20250227110208.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/53020866519',
#   'lprice': '53900',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '53020866519',
#   'productType': '1',
#   'title': '셀렙샵에디션 알파카 캔디 니트<b>가디건</b>'},
#  {'brand': '스파오',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5165906/51659066776.20250313113232.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/51659066776',
#   'lprice': '20720',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '51659066776',
#   'productType': '1',
#   'title': '스파오 라운드넥 <b>카디건</b> SPCKF23W01'},
#  {'brand': '사색',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5356868/53568688511.20250324112403.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/53568688511',
#   'lprice': '37800',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '53568688511',
#   'productType': '1',
#   'title': '사색 젤라 크롭트 슬림 <b>가디건</b>'},
#  {'brand': '모르간',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5050463/50504636053.20240926182452.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/50504636053',
#   'lprice': '51460',
#   'maker': '모르간',
#   'mallName': '네이버',
#   'productId': '50504636053',
#   'productType': '1',
#   'title': '모르간 24FW 반팔 울 니트<b>가디건</b> 3종 88'},
#  {'brand': '제이플로우',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8564817/85648174636.jpg',
#   'link': 'https://smartstore.naver.com/main/products/8103674313',
#   'lprice': '41800',
#   'maker': '',
#   'mallName': '제이플로우',
#   'productId': '85648174636',
#   'productType': '2',
#   'title': '머핀 도톰 루즈핏 숄 울니트 롱<b>가디건</b> 3col 봄 겨울 오버핏 고급원사 노카라 제이플로우'},
#  {'brand': '쉬즈미스',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5252346/52523460806.20250309134119.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52523460806',
#   'lprice': '30830',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52523460806',
#   'productType': '1',
#   'title': '쉬즈미스 글리터 펀칭 브이넥 <b>가디건</b> SSKCDO11080'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8230898/82308983052.26.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4764461132',
#   'lprice': '209000',
#   'maker': '폴로랄프로렌',
#   'mallName': '동부산아울렛명품관',
#   'productId': '82308983052',
#   'productType': '2',
#   'title': '(백화점AS가능/쇼핑백) 폴로 랄프로렌 여성 피마코튼 <b>가디건</b> 12color'},
#  {'brand': '제너럴아이디어',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5213150/52131507480.20250203034643.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52131507480',
#   'lprice': '31000',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52131507480',
#   'productType': '1',
#   'title': '제너럴아이디어 WOMAN 시그니처 슈퍼파인 울 케이블 <b>가디건</b> 4COL WBD3L04505'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4980867/49808672747.jpg',
#   'link': 'https://display.cjonstyle.com/p/item/2037627162?infl_cd=I0696&utm_medium=pcs&utm_source=naver',
#   'lprice': '159000',
#   'maker': '폴로랄프로렌',
#   'mallName': 'CJ온스타일',
#   'productId': '49808672747',
#   'productType': '2',
#   'title': '[POLO RALPH LAUREN] 폴로 랄프로렌 여성 코튼 블렌드 <b>가디건</b> 다크그레이'},
#  {'brand': '메종키츠네',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8596612/85966127560.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/8421627237',
#   'lprice': '258500',
#   'maker': '메종키츠네',
#   'mallName': '조하리스토어',
#   'productId': '85966127560',
#   'productType': '2',
#   'title': '메종키츠네 <b>가디건</b> 더블 폭스헤드 칠렉스 베이비폭스'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8754962/87549627574.jpg',
#   'link': 'https://smartstore.naver.com/main/products/10005125301',
#   'lprice': '118600',
#   'maker': '폴로랄프로렌',
#   'mallName': '피로스',
#   'productId': '87549627574',
#   'productType': '2',
#   'title': '폴로 랄프로렌 여성 심플 기본 라운드넥 피마코튼 <b>가디건</b>'},
#  {'brand': '타미힐피거',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4080491/40804917010.20240913233032.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/40804917010',
#   'lprice': '59900',
#   'maker': '타미힐피거',
#   'mallName': '네이버',
#   'productId': '40804917010',
#   'productType': '1',
#   'title': '타미힐피거 여성 라운드 넥 버튼 다운 긴팔 <b>가디건</b> 4색'},
#  {'brand': 'BNX',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5248336/52483360456.20250114161304.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52483360456',
#   'lprice': '15065',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52483360456',
#   'productType': '1',
#   'title': 'BNX 캐릭터 자수 포인트 버튼업 니트 <b>가디건</b> BW3CD009L0'},
#  {'brand': '올리브데올리브',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5275209/52752095274.20250205005812.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52752095274',
#   'lprice': '24900',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52752095274',
#   'productType': '1',
#   'title': '아울렛상품 올리브데올리브 올리브데올리브 시스루 브이넥 니트 <b>가디건</b> YK4AD706'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8663762/86637620614.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9093120291',
#   'lprice': '126000',
#   'maker': '',
#   'mallName': '버터프레즐마켓',
#   'productId': '86637620614',
#   'productType': '2',
#   'title': '파운더스 라쿤 트윈 세트, 니트 <b>가디건</b> 세트 4color'},
#  {'brand': '꼼데가르송',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8583104/85831045317.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/8286544994',
#   'lprice': '254290',
#   'maker': '꼼데가르송',
#   'mallName': '아임재팬',
#   'productId': '85831045317',
#   'productType': '2',
#   'title': '꼼데가르송 <b>가디건</b> V넥 U넥 블랙와펜 레드와펜'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8425873/84258735811.jpg',
#   'link': 'https://smartstore.naver.com/main/products/6714235489',
#   'lprice': '29500',
#   'maker': '',
#   'mallName': '멜빈트 MELVINT',
#   'productId': '84258735811',
#   'productType': '2',
#   'title': '여성 여름 로브 <b>가디건</b> 에스닉 빅사이즈 린넨 로브 비치 멜빈트'},
#  {'brand': '폴로',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5335412/53354122201.2.jpg',
#   'link': 'http://gate.halfclub.com/naver?site_cd=1&type=detail_pcode&p1=P385305412&partnerid=naverdb',
#   'lprice': '74500',
#   'maker': '폴로',
#   'mallName': '하프클럽',
#   'productId': '53354122201',
#   'productType': '2',
#   'title': '[폴로] 특가 POLO RALPH LAUREN 여성용 피마코튼 블렌드 <b>가디건</b>.'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8576806/85768067670.21.jpg',
#   'link': 'https://smartstore.naver.com/main/products/8223567347',
#   'lprice': '27300',
#   'maker': '',
#   'mallName': '마이이너웨어',
#   'productId': '85768067670',
#   'productType': '2',
#   'title': '여성 폼 플라워 꽃자수 봄 니트 <b>가디건</b> 빅사이즈'},
#  {'brand': '피카부',
#   'category1': '출산/육아',
#   'category2': '유아동의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8232797/82327977570.35.jpg',
#   'link': 'https://smartstore.naver.com/main/products/4783455109',
#   'lprice': '15300',
#   'maker': '',
#   'mallName': '베베드키즈',
#   'productId': '82327977570',
#   'productType': '2',
#   'title': '아기<b>가디건</b> 유아 여아 남아 키즈 주니어 신생아 봄 여름 가을'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5005339/50053399067.jpg',
#   'link': 'https://www.chicfox.co.kr/index.html?branduid=511277&ref=naver_open',
#   'lprice': '29800',
#   'maker': '',
#   'mallName': '시크폭스',
#   'productId': '50053399067',
#   'productType': '2',
#   'title': '코스에그 자수 투웨이 니트집업 <b>가디건</b>'},
#  {'brand': '마뗑킴',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8716008/87160082906.12.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9615580636',
#   'lprice': '199000',
#   'maker': '',
#   'mallName': 'STOCK TAKER',
#   'productId': '87160082906',
#   'productType': '2',
#   'title': '국내매장 마뗑킴 스펠 포인트 <b>가디건</b> 니트 집업 SPELL POINT 블랙 아이보리'},
#  {'brand': '라삐아프',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5248211/52482116627.20250114140149.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52482116627',
#   'lprice': '65010',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52482116627',
#   'productType': '1',
#   'title': '라삐아프 도톰 <b>가디건</b> 3종'},
#  {'brand': '메종키츠네',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5070378/50703782063.20250110000326.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/50703782063',
#   'lprice': '126300',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '50703782063',
#   'productType': '1',
#   'title': '메종키츠네 여성 더블 폭스 헤드 <b>가디건</b> H250 GW00544KT1036'},
#  {'brand': '꼼데가르송',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8285689/82856891636.6.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5312399174',
#   'lprice': '325000',
#   'maker': '꼼데가르송',
#   'mallName': '동쿄모찌',
#   'productId': '82856891636',
#   'productType': '2',
#   'title': '(국내당일발송)꼼데가르송 블랙 레드 와펜 <b>가디건</b> / 여성 남성용'},
#  {'brand': '후아유',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4971517/49715176984.20250406004401.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/49715176984',
#   'lprice': '27810',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '49715176984',
#   'productType': '1',
#   'title': '후아유 스티브 케이블 <b>가디건</b> WHCKE4901F'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8316097/83160975112.2.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5616478597',
#   'lprice': '27800',
#   'maker': '',
#   'mallName': '로우라이트',
#   'productId': '83160975112',
#   'productType': '2',
#   'title': '린넨<b>가디건</b> 여름<b>가디건</b> 크롭<b>가디건</b>'},
#  {'brand': '폴로랄프로렌',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8620259/86202596545.6.jpg',
#   'link': 'https://smartstore.naver.com/main/products/8658096222',
#   'lprice': '79000',
#   'maker': '폴로랄프로렌',
#   'mallName': '프롬투',
#   'productId': '86202596545',
#   'productType': '2',
#   'title': '[백화점] 폴로 보이즈 남녀공용 케이블 꽈배기 브이넥 <b>가디건</b>'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8678397/86783973661.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9239473338',
#   'lprice': '24500',
#   'maker': '',
#   'mallName': '메일리Maily',
#   'productId': '86783973661',
#   'productType': '2',
#   'title': '메일리 도톰 니트 집업 세일러 카라 봄 가을 여자 여성 숏 세미 크롭 지퍼 <b>가디건</b> 자켓'},
#  {'brand': '아미',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8746977/87469778447.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9925276174',
#   'lprice': '349000',
#   'maker': 'AMI',
#   'mallName': '버닝웨어',
#   'productId': '87469778447',
#   'productType': '2',
#   'title': '24FW 아미 <b>가디건</b> 메리노 울 블랙 BFHKC001 001 001'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8667127/86671274005.1.jpg',
#   'link': 'https://smartstore.naver.com/main/products/9126773681',
#   'lprice': '62000',
#   'maker': '',
#   'mallName': '마드제이',
#   'productId': '86671274005',
#   'productType': '2',
#   'title': '(베 당일) 단독제작!! 마드제이 셀린 라인 <b>가디건</b>'},
#  {'brand': '꼼데가르송',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8314138/83141381630.3.jpg',
#   'link': 'https://smartstore.naver.com/main/products/5596885309',
#   'lprice': '322900',
#   'maker': '꼼데가르송',
#   'mallName': '동쿄모찌',
#   'productId': '83141381630',
#   'productType': '2',
#   'title': '(국내당일발송) 꼼데가르송 <b>가디건</b> 화이트와펜 라운드 브이넥'},
#  {'brand': '지오다노',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5250734/52507346449.20250316055019.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52507346449',
#   'lprice': '30880',
#   'maker': '지오다노',
#   'mallName': '네이버',
#   'productId': '52507346449',
#   'productType': '1',
#   'title': '지오다노 NEW 여자 면 혼방 꽈배기 버튼 <b>가디건</b> 355504'},
#  {'brand': '폴로',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_4385462/43854620075.4.jpg',
#   'link': 'https://display.cjonstyle.com/p/item/2022517129?infl_cd=I0696&utm_medium=pcs&utm_source=naver',
#   'lprice': '139000',
#   'maker': '폴로',
#   'mallName': 'CJ온스타일',
#   'productId': '43854620075',
#   'productType': '2',
#   'title': '폴로 랄프로렌 코튼블렌디드 <b>가디건</b> 여성'},
#  {'brand': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8782997/87829978335.jpg',
#   'link': 'https://smartstore.naver.com/main/products/10285474476',
#   'lprice': '19900',
#   'maker': '',
#   'mallName': 'ARUMY',
#   'productId': '87829978335',
#   'productType': '2',
#   'title': '9color 여름 얇은 비치<b>가디건</b> 시스루 커버업 니트 숏 크롭 <b>가디건</b> 화이트 블랙 핑크'},
#  {'brand': '사색',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5252514/52525143696.20250402054333.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52525143696',
#   'lprice': '49700',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52525143696',
#   'productType': '1',
#   'title': '사색 블루아 V 파인울 랩 <b>가디건</b>'},
#  {'brand': '게스',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5331951/53319519216.20250404071127.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/53319519216',
#   'lprice': '137260',
#   'maker': '게스',
#   'mallName': '네이버',
#   'productId': '53319519216',
#   'productType': '1',
#   'title': '게스 게스진 SUZY 여성 데님믹스 입체격자 스웨터 <b>가디건</b> YP1S2660'},
#  {'brand': '올리브데올리브',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_5266297/52662970843.20250223001429.jpg',
#   'link': 'https://search.shopping.naver.com/catalog/52662970843',
#   'lprice': '33200',
#   'maker': '',
#   'mallName': '네이버',
#   'productId': '52662970843',
#   'productType': '1',
#   'title': '올리브데올리브 슬림핏 브이넥 <b>가디건</b> YK5SD417'},
#  {'brand': '트리플에이',
#   'category1': '패션의류',
#   'category2': '남성의류',
#   'category3': '카디건',
#   'category4': '',
#   'hprice': '',
#   'image': 'https://shopping-phinf.pstatic.net/main_8483758/84837584339.jpg',
#   'link': 'https://shopping.naver.com/outlink/itemdetail/7293084017',
#   'lprice': '39800',
#   'maker': '',
#   'mallName': '용된다',
#   'productId': '84837584339',
#   'productType': '2',
#   'title': '봄 가을 남자 오버핏 <b>가디건</b> 남자니트집업 투웨이'}]

# %%
def print_shop_item(idx, item):
    lprice = int(item.get('lprice', 0))
    print(f"\n{idx}. {item['title'].replace('<b>', '').replace('</b>', '')}")
    print(f"   최저가: {lprice:,}원")
    print(f"   브랜드: {item.get('brand', '정보없음')}")
    print(f"   쇼핑몰: {item.get('mallName', '정보없음')}")
    print(f"   링크: {item['link']}")

# %%
print("\n=== 쇼핑 검색 결과 ===")
for idx, item in enumerate(items_data, 1):
    print_shop_item(idx, item)
# Out:
# === 쇼핑 검색 결과 ===
#
# 1. 백화점3-5일배송 폴로 가디건 걸즈 걸스 랄프로렌 꽈배기 블랙 화이트 핑크 헌터네이비XL
#    최저가: 64,900원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 나우인뉴욕
#    링크: https://smartstore.naver.com/main/products/6672150068
#
# 2. 봄 가을 간절기 라운드 루즈핏 크롭 가디건 레드 그린 핑크 화이트 블랙 옐로우
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/5466947569
#
# 3. [백화점3-5일배송] 폴로 가디건 니트 걸즈 랄프로렌 블랙 화이트 핑크 헌터네이비XL L
#    최저가: 63,900원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 트위티 155
#    링크: https://smartstore.naver.com/main/products/8450462001
#
# 4. 부드러운 캐시미어 크롭 가디건 숏 라운드 니트가디건 여성 가디건 봄 간절기 레드 핑크
#    최저가: 18,900원
#    브랜드:
#    쇼핑몰: 코이블리
#    링크: https://smartstore.naver.com/main/products/4828155463
#
# 5. [백화점] 폴로 가디건 걸즈 케이블 꽈배기 니트
#    최저가: 69,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 세컨찬스라이프
#    링크: https://smartstore.naver.com/main/products/11107384300
#
# 6. 꼼데가르송 기본와펜 가디건 여성용
#    최저가: 254,390원
#    브랜드: 꼼데가르송
#    쇼핑몰: 레이바쿠
#    링크: https://smartstore.naver.com/main/products/4741606965
#
# 7. 메종키츠네 가디건 베이비폭스 폭스헤드 더블폭스 칠랙스 [당일출고]
#    최저가: 267,000원
#    브랜드: 메종키츠네
#    쇼핑몰: 브랜드리퍼블릭
#    링크: https://smartstore.naver.com/main/products/5302659122
#
# 8. (8컬러)폴로랄프로렌 피마코튼 여성 가디건
#    최저가: 209,000원
#    브랜드: 폴로
#    쇼핑몰: 바이찬스
#    링크: https://smartstore.naver.com/main/products/3427657202
#
# 9. [미국 백화점] 폴로 가디건 걸스 걸즈 랄프로렌 꽈배기 케이블 니트 가디건 네이비 블랙 핑크 화이트 L XL
#    최저가: 59,900원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 뉴욕바잉
#    링크: https://smartstore.naver.com/main/products/5766048400
#
# 10. 드온도 노튼 캐시미어 가디건 봄 스프링 라운드 니트 deondo
#    최저가: 49,500원
#    브랜드:
#    쇼핑몰: 루나드엘
#    링크: https://smartstore.naver.com/main/products/9971634198
#
# 11. 제너럴아이디어 WOMAN GNRL 에센셜 베이직 카디건 11COL WBD3L04503
#    최저가: 32,400원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53287208769
#
# 12. H&amp;M HM 파인 니트 가디건 0579541001
#    최저가: 17,512원
#    브랜드: H&M
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51781610172
#
# 13. [국내발송 + 선물포장] 폴로 랄프로렌 여아 아기 코튼 베이비 가디건 핑크 옐로우 화이트
#    최저가: 69,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 리틀데이즈
#    링크: https://smartstore.naver.com/main/products/9459545518
#
# 14. [국내배송] 꼼데가르송 가디건 기본와펜 여성/남성용
#    최저가: 315,800원
#    브랜드: 꼼데가르송
#    쇼핑몰: 브랜드사는이쁜언니
#    링크: https://smartstore.naver.com/main/products/7945338110
#
# 15. 레이어드가디건 캐시미어가디건 여자봄가디건 사무실
#    최저가: 29,800원
#    브랜드:
#    쇼핑몰: 미드시티 여성니트
#    링크: https://smartstore.naver.com/main/products/10064618231
#
# 16. 라코스테 남성 베이직 V넥 방모 가디건 AH560E-54N
#    최저가: 80,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49714141886
#
# 17. (당일) 프리티영띵 뉴 페블 골지 가디건 PYT 프영띵 떠유니
#    최저가: 42,000원
#    브랜드:
#    쇼핑몰: ttoyuni
#    링크: https://smartstore.naver.com/main/products/9044880794
#
# 18. 여자 보풀없는 캐시미어 비스코스 니트 여성 라운드 가디건 인디핑크 병원 간호 사무실
#    최저가: 29,900원
#    브랜드:
#    쇼핑몰: 지읒이응
#    링크: https://smartstore.naver.com/main/products/5391580059
#
# 19. [우체국당일발송] 폴로 걸즈 가디건 XL / 폴로 랄프로렌 걸즈 케이블 니트 꽈배기 가디건
#    최저가: 115,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 트렌드홀릭
#    링크: https://smartstore.naver.com/main/products/6629506201
#
# 20. 톰브라운 가디건 울 밀라노 스티치 MKC002A
#    최저가: 809,000원
#    브랜드: 톰브라운
#    쇼핑몰: 버닝웨어
#    링크: https://smartstore.naver.com/main/products/6566315211
#
# 21. 시스루 얇은 린넨 루즈핏 니트 여름 여성 가디건 (올타임)
#    최저가: 23,900원
#    브랜드:
#    쇼핑몰: 고고하니
#    링크: https://smartstore.naver.com/main/products/5592080655
#
# 22. 티블러썸 결혼식 하객룩 진주단추 가디건 봄 퍼프 니트 여성 금장 크롭 가디건 6color
#    최저가: 27,000원
#    브랜드:
#    쇼핑몰: 건강한생활82
#    링크: https://smartstore.naver.com/main/products/7984870784
#
# 23. 포인즈 부드럽고 포근해 얇은 니트 울 오버핏 가디건 여성 가디건 겨울 봄
#    최저가: 24,800원
#    브랜드:
#    쇼핑몰: 베이지블랑.
#    링크: https://smartstore.naver.com/main/products/5194780033
#
# 24. 10COLOR 여성 봄 비비드컬러 라운드 슬릿넥 크롭 니트 그린 핑크가디건
#    최저가: 24,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/9959540751
#
# 25. 예가체프 R 파인울 가디건
#    최저가: 43,700원
#    브랜드: 사색
#    쇼핑몰: 사색
#    링크: https://smartstore.naver.com/main/products/11333309394
#
# 26. [QR인증백화점] 폴로 가디건 걸즈 여성 케이블 꽈배기 니트
#    최저가: 68,700원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 부스더샵
#    링크: https://smartstore.naver.com/main/products/11222372847
#
# 27. 벤시몽 여성 코튼 블렌드 케이블 가디건 3종
#    최저가: 44,910원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53232763110
#
# 28. 남자가디건 울 라운드 캐시미어 오버핏 하찌 니트 커플가디건 봄 가을
#    최저가: 39,800원
#    브랜드:
#    쇼핑몰: 왓위웨어
#    링크: https://smartstore.naver.com/main/products/5290981221
#
# 29. 리스트 라운드넥 버튼 니트 가디건 TSKCDO72010
#    최저가: 23,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51143733510
#
# 30. 제너럴아이디어 GENERALIDEA WOMAN 에센셜 크루넥 가디건 4COL WBD3L04501
#    최저가: 31,416원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49541497760
#
# 31. 비비안웨스트우드 여성 베아 울 실크 가디건 1803001Z
#    최저가: 28,070원
#    브랜드: 비비안웨스트우드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/43475137325
#
# 32. 폴로 랄프로렌 케이블 가디건 보이즈 (3컬러)
#    최저가: 129,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 포니홀릭
#    링크: https://smartstore.naver.com/main/products/9180341475
#
# 33. 꼼데가르송 기본와펜 가디건 남성용
#    최저가: 254,300원
#    브랜드: 꼼데가르송
#    쇼핑몰: 레이바쿠
#    링크: https://smartstore.naver.com/main/products/4727598933
#
# 34. 꼼데가르송 꼼데 가디건 여성 남성 니트
#    최저가: 329,000원
#    브랜드: 꼼데가르송
#    쇼핑몰: 도쿄루꼬
#    링크: https://smartstore.naver.com/main/products/5924539032
#
# 35. [백화점] 폴로 랄프로렌 남자 코튼 브이넥 가디건 (4컬러)
#    최저가: 159,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 포니홀릭
#    링크: https://smartstore.naver.com/main/products/9097681985
#
# 36. 카렌 여름 가을 간절기 여자 아기가디건 유아가디건 3개월 6개월 9개월 돌아기
#    최저가: 19,800원
#    브랜드:
#    쇼핑몰: 로이앤한나
#    링크: https://smartstore.naver.com/main/products/4901850589
#
# 37. 메종키츠네 가디건 폭스헤드 트리컬러 베이비폭스 볼드폭스
#    최저가: 259,000원
#    브랜드: 메종키츠네
#    쇼핑몰: 브랜드리퍼블릭
#    링크: https://smartstore.naver.com/main/products/4893542136
#
# 38. 루즈핏 캐시미어 브이넥가디건 숏 크롭 여성가디건 니트가디건 봄 간절기 레드 핑크 블랙
#    최저가: 18,900원
#    브랜드:
#    쇼핑몰: 코이블리
#    링크: https://smartstore.naver.com/main/products/4382440024
#
# 39. 허브 R 크롭트 가디건
#    최저가: 39,700원
#    브랜드: 사색
#    쇼핑몰: 사색
#    링크: https://smartstore.naver.com/main/products/11515283775
#
# 40. 라코스테 여성 케이블 크루넥 가디건 AF091E-54N
#    최저가: 143,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49912758699
#
# 41. LE TROIS 23FW 르투아 투웨이 니트 집업 카라 가디건 2종 세트
#    최저가: 13,100원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53690259105
#
# 42. 비비안웨스트우드 가디건 여성 화이트라벨 선물패키지
#    최저가: 261,000원
#    브랜드: 비비안웨스트우드
#    쇼핑몰: 브랜드리퍼블릭
#    링크: https://smartstore.naver.com/main/products/6260556498
#
# 43. 리스트 라운드넥 루즈핏 가디건 TSKCDO72520
#    최저가: 24,940원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49580876217
#
# 44. 벤시몽 여성 케이블 니트 가디건 3종
#    최저가: 37,650원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53373694627
#
# 45. 쉬즈미스 메탈 라운드넥 니트 가디건 SSKCDO31060
#    최저가: 36,910원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49625464649
#
# 46. 베네통스포츠 베네통스포츠 여성 니트 가디건 2종
#    최저가: 85,980원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53126962083
#
# 47. 꼼데가르송 화이트와펜 가디건 여성용
#    최저가: 292,800원
#    브랜드: 꼼데가르송
#    쇼핑몰: 레이바쿠
#    링크: https://smartstore.naver.com/main/products/4368011188
#
# 48. 로엠 브이넥 가디건 RMCKF23R98
#    최저가: 44,910원
#    브랜드: 로엠
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52675721484
#
# 49. 타미힐피거 가디건 여자 베이직 코튼 비스코스 라운드넥 니트 티셔츠
#    최저가: 69,000원
#    브랜드: 타미힐피거
#    쇼핑몰: 빨간단풍 구매대행
#    링크: https://smartstore.naver.com/main/products/8472076845
#
# 50. 라코스테 남성 피케 조직 V넥 울가디건 AH697E-54N
#    최저가: 174,090원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50705955349
#
# 51. 메종키츠네 가디건 폭스헤드 더블폭스 베이비폭스
#    최저가: 298,000원
#    브랜드: 메종키츠네
#    쇼핑몰: 버닝웨어
#    링크: https://smartstore.naver.com/main/products/5298295067
#
# 52. 톰브라운 남성 가디건 415 MJT167A 00535
#    최저가: 671,030원
#    브랜드: 톰브라운
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52101774528
#
# 53. [백화점당일출고] 타미 힐피거 남성 풀 집업 코튼 니트 남자 가디건
#    최저가: 65,900원
#    브랜드: 타미힐피거
#    쇼핑몰: 나우인뉴욕
#    링크: https://smartstore.naver.com/main/products/9454099287
#
# 54. 제너럴아이디어 제너럴 아이디어 WOMAN 멀티 스트라이프 크루넥 가디건 남색 NA WBE1L04504NA
#    최저가: 32,472원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52384299518
#
# 55. 리스트 리스트 아웃 포켓 크롭 가디건 TSKCDO70030
#    최저가: 24,020원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51690622371
#
# 56. 폴햄 여성 자켓형 가디건 PHF1EC2030
#    최저가: 28,380원
#    브랜드: 폴햄
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51964323969
#
# 57. 미쏘 에센셜 브이넥 베이직 가디건 MIWCKE920T
#    최저가: 11,690원
#    브랜드: 미쏘
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49441291447
#
# 58. 폴로랄프로렌 폴로 랄프로렌 여성 코튼 블렌드 가디건
#    최저가: 125,400원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/45723735727
#
# 59. 제이슨우 Spring 가디건 3종
#    최저가: 74,310원
#    브랜드: 제이슨우
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52482107751
#
# 60. 유니클로 UV PROTECTION 크루넥 여성 가디건 자외선차단 봄 간절기 빅사이즈
#    최저가: 49,800원
#    브랜드: 유니클로
#    쇼핑몰: 더헤르츠
#    링크: https://smartstore.naver.com/main/products/10061021121
#
# 61. 아미 AMI 스몰 하트 남성 울 가디건 491 HKC001 001
#    최저가: 279,000원
#    브랜드: 아미
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50931741210
#
# 62. 셀렙샵에디션 알파카 캔디 니트가디건
#    최저가: 53,900원
#    브랜드: 셀렙샵에디션
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53020866519
#
# 63. 스파오 라운드넥 카디건 SPCKF23W01
#    최저가: 20,720원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51659066776
#
# 64. 사색 젤라 크롭트 슬림 가디건
#    최저가: 37,800원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53568688511
#
# 65. 모르간 24FW 반팔 울 니트가디건 3종 88
#    최저가: 51,460원
#    브랜드: 모르간
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50504636053
#
# 66. 머핀 도톰 루즈핏 숄 울니트 롱가디건 3col 봄 겨울 오버핏 고급원사 노카라 제이플로우
#    최저가: 41,800원
#    브랜드: 제이플로우
#    쇼핑몰: 제이플로우
#    링크: https://smartstore.naver.com/main/products/8103674313
#
# 67. 쉬즈미스 글리터 펀칭 브이넥 가디건 SSKCDO11080
#    최저가: 30,830원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52523460806
#
# 68. (백화점AS가능/쇼핑백) 폴로 랄프로렌 여성 피마코튼 가디건 12color
#    최저가: 209,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 동부산아울렛명품관
#    링크: https://smartstore.naver.com/main/products/4764461132
#
# 69. 제너럴아이디어 WOMAN 시그니처 슈퍼파인 울 케이블 가디건 4COL WBD3L04505
#    최저가: 31,000원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52131507480
#
# 70. [POLO RALPH LAUREN] 폴로 랄프로렌 여성 코튼 블렌드 가디건 다크그레이
#    최저가: 159,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: CJ온스타일
#    링크: https://display.cjonstyle.com/p/item/2037627162?infl_cd=I0696&utm_medium=pcs&utm_source=naver
#
# 71. 메종키츠네 가디건 더블 폭스헤드 칠렉스 베이비폭스
#    최저가: 258,500원
#    브랜드: 메종키츠네
#    쇼핑몰: 조하리스토어
#    링크: https://smartstore.naver.com/main/products/8421627237
#
# 72. 폴로 랄프로렌 여성 심플 기본 라운드넥 피마코튼 가디건
#    최저가: 118,600원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 피로스
#    링크: https://smartstore.naver.com/main/products/10005125301
#
# 73. 타미힐피거 여성 라운드 넥 버튼 다운 긴팔 가디건 4색
#    최저가: 59,900원
#    브랜드: 타미힐피거
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/40804917010
#
# 74. BNX 캐릭터 자수 포인트 버튼업 니트 가디건 BW3CD009L0
#    최저가: 15,065원
#    브랜드: BNX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52483360456
#
# 75. 아울렛상품 올리브데올리브 올리브데올리브 시스루 브이넥 니트 가디건 YK4AD706
#    최저가: 24,900원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52752095274
#
# 76. 파운더스 라쿤 트윈 세트, 니트 가디건 세트 4color
#    최저가: 126,000원
#    브랜드:
#    쇼핑몰: 버터프레즐마켓
#    링크: https://smartstore.naver.com/main/products/9093120291
#
# 77. 꼼데가르송 가디건 V넥 U넥 블랙와펜 레드와펜
#    최저가: 254,290원
#    브랜드: 꼼데가르송
#    쇼핑몰: 아임재팬
#    링크: https://smartstore.naver.com/main/products/8286544994
#
# 78. 여성 여름 로브 가디건 에스닉 빅사이즈 린넨 로브 비치 멜빈트
#    최저가: 29,500원
#    브랜드:
#    쇼핑몰: 멜빈트 MELVINT
#    링크: https://smartstore.naver.com/main/products/6714235489
#
# 79. [폴로] 특가 POLO RALPH LAUREN 여성용 피마코튼 블렌드 가디건.
#    최저가: 74,500원
#    브랜드: 폴로
#    쇼핑몰: 하프클럽
#    링크: http://gate.halfclub.com/naver?site_cd=1&type=detail_pcode&p1=P385305412&partnerid=naverdb
#
# 80. 여성 폼 플라워 꽃자수 봄 니트 가디건 빅사이즈
#    최저가: 27,300원
#    브랜드:
#    쇼핑몰: 마이이너웨어
#    링크: https://smartstore.naver.com/main/products/8223567347
#
# 81. 아기가디건 유아 여아 남아 키즈 주니어 신생아 봄 여름 가을
#    최저가: 15,300원
#    브랜드: 피카부
#    쇼핑몰: 베베드키즈
#    링크: https://smartstore.naver.com/main/products/4783455109
#
# 82. 코스에그 자수 투웨이 니트집업 가디건
#    최저가: 29,800원
#    브랜드:
#    쇼핑몰: 시크폭스
#    링크: https://www.chicfox.co.kr/index.html?branduid=511277&ref=naver_open
#
# 83. 국내매장 마뗑킴 스펠 포인트 가디건 니트 집업 SPELL POINT 블랙 아이보리
#    최저가: 199,000원
#    브랜드: 마뗑킴
#    쇼핑몰: STOCK TAKER
#    링크: https://smartstore.naver.com/main/products/9615580636
#
# 84. 라삐아프 도톰 가디건 3종
#    최저가: 65,010원
#    브랜드: 라삐아프
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52482116627
#
# 85. 메종키츠네 여성 더블 폭스 헤드 가디건 H250 GW00544KT1036
#    최저가: 126,300원
#    브랜드: 메종키츠네
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50703782063
#
# 86. (국내당일발송)꼼데가르송 블랙 레드 와펜 가디건 / 여성 남성용
#    최저가: 325,000원
#    브랜드: 꼼데가르송
#    쇼핑몰: 동쿄모찌
#    링크: https://smartstore.naver.com/main/products/5312399174
#
# 87. 후아유 스티브 케이블 가디건 WHCKE4901F
#    최저가: 27,810원
#    브랜드: 후아유
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49715176984
#
# 88. 린넨가디건 여름가디건 크롭가디건
#    최저가: 27,800원
#    브랜드:
#    쇼핑몰: 로우라이트
#    링크: https://smartstore.naver.com/main/products/5616478597
#
# 89. [백화점] 폴로 보이즈 남녀공용 케이블 꽈배기 브이넥 가디건
#    최저가: 79,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 프롬투
#    링크: https://smartstore.naver.com/main/products/8658096222
#
# 90. 메일리 도톰 니트 집업 세일러 카라 봄 가을 여자 여성 숏 세미 크롭 지퍼 가디건 자켓
#    최저가: 24,500원
#    브랜드:
#    쇼핑몰: 메일리Maily
#    링크: https://smartstore.naver.com/main/products/9239473338
#
# 91. 24FW 아미 가디건 메리노 울 블랙 BFHKC001 001 001
#    최저가: 349,000원
#    브랜드: 아미
#    쇼핑몰: 버닝웨어
#    링크: https://smartstore.naver.com/main/products/9925276174
#
# 92. (베 당일) 단독제작!! 마드제이 셀린 라인 가디건
#    최저가: 62,000원
#    브랜드:
#    쇼핑몰: 마드제이
#    링크: https://smartstore.naver.com/main/products/9126773681
#
# 93. (국내당일발송) 꼼데가르송 가디건 화이트와펜 라운드 브이넥
#    최저가: 322,900원
#    브랜드: 꼼데가르송
#    쇼핑몰: 동쿄모찌
#    링크: https://smartstore.naver.com/main/products/5596885309
#
# 94. 지오다노 NEW 여자 면 혼방 꽈배기 버튼 가디건 355504
#    최저가: 30,880원
#    브랜드: 지오다노
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52507346449
#
# 95. 폴로 랄프로렌 코튼블렌디드 가디건 여성
#    최저가: 139,000원
#    브랜드: 폴로
#    쇼핑몰: CJ온스타일
#    링크: https://display.cjonstyle.com/p/item/2022517129?infl_cd=I0696&utm_medium=pcs&utm_source=naver
#
# 96. 9color 여름 얇은 비치가디건 시스루 커버업 니트 숏 크롭 가디건 화이트 블랙 핑크
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/10285474476
#
# 97. 사색 블루아 V 파인울 랩 가디건
#    최저가: 49,700원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52525143696
#
# 98. 게스 게스진 SUZY 여성 데님믹스 입체격자 스웨터 가디건 YP1S2660
#    최저가: 137,260원
#    브랜드: 게스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53319519216
#
# 99. 올리브데올리브 슬림핏 브이넥 가디건 YK5SD417
#    최저가: 33,200원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52662970843
#
# 100. 봄 가을 남자 오버핏 가디건 남자니트집업 투웨이
#    최저가: 39,800원
#    브랜드: 트리플에이
#    쇼핑몰: 용된다
#    링크: https://shopping.naver.com/outlink/itemdetail/7293084017

# %%
print("\n=== 50,000원 이하 상품 ===")
idx = 1
for item in items_data:
    if int(item.get('lprice', 0)) <= 50000:
        print_shop_item(idx, item)
        idx += 1  # 조건 통과할 때만 증가
# Out:
# === 50,000원 이하 상품 ===
#
# 1. 봄 가을 간절기 라운드 루즈핏 크롭 가디건 레드 그린 핑크 화이트 블랙 옐로우
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/5466947569
#
# 2. 부드러운 캐시미어 크롭 가디건 숏 라운드 니트가디건 여성 가디건 봄 간절기 레드 핑크
#    최저가: 18,900원
#    브랜드:
#    쇼핑몰: 코이블리
#    링크: https://smartstore.naver.com/main/products/4828155463
#
# 3. 드온도 노튼 캐시미어 가디건 봄 스프링 라운드 니트 deondo
#    최저가: 49,500원
#    브랜드:
#    쇼핑몰: 루나드엘
#    링크: https://smartstore.naver.com/main/products/9971634198
#
# 4. 제너럴아이디어 WOMAN GNRL 에센셜 베이직 카디건 11COL WBD3L04503
#    최저가: 32,400원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53287208769
#
# 5. H&amp;M HM 파인 니트 가디건 0579541001
#    최저가: 17,512원
#    브랜드: H&M
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51781610172
#
# 6. 레이어드가디건 캐시미어가디건 여자봄가디건 사무실
#    최저가: 29,800원
#    브랜드:
#    쇼핑몰: 미드시티 여성니트
#    링크: https://smartstore.naver.com/main/products/10064618231
#
# 7. (당일) 프리티영띵 뉴 페블 골지 가디건 PYT 프영띵 떠유니
#    최저가: 42,000원
#    브랜드:
#    쇼핑몰: ttoyuni
#    링크: https://smartstore.naver.com/main/products/9044880794
#
# 8. 여자 보풀없는 캐시미어 비스코스 니트 여성 라운드 가디건 인디핑크 병원 간호 사무실
#    최저가: 29,900원
#    브랜드:
#    쇼핑몰: 지읒이응
#    링크: https://smartstore.naver.com/main/products/5391580059
#
# 9. 시스루 얇은 린넨 루즈핏 니트 여름 여성 가디건 (올타임)
#    최저가: 23,900원
#    브랜드:
#    쇼핑몰: 고고하니
#    링크: https://smartstore.naver.com/main/products/5592080655
#
# 10. 티블러썸 결혼식 하객룩 진주단추 가디건 봄 퍼프 니트 여성 금장 크롭 가디건 6color
#    최저가: 27,000원
#    브랜드:
#    쇼핑몰: 건강한생활82
#    링크: https://smartstore.naver.com/main/products/7984870784
#
# 11. 포인즈 부드럽고 포근해 얇은 니트 울 오버핏 가디건 여성 가디건 겨울 봄
#    최저가: 24,800원
#    브랜드:
#    쇼핑몰: 베이지블랑.
#    링크: https://smartstore.naver.com/main/products/5194780033
#
# 12. 10COLOR 여성 봄 비비드컬러 라운드 슬릿넥 크롭 니트 그린 핑크가디건
#    최저가: 24,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/9959540751
#
# 13. 예가체프 R 파인울 가디건
#    최저가: 43,700원
#    브랜드: 사색
#    쇼핑몰: 사색
#    링크: https://smartstore.naver.com/main/products/11333309394
#
# 14. 벤시몽 여성 코튼 블렌드 케이블 가디건 3종
#    최저가: 44,910원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53232763110
#
# 15. 남자가디건 울 라운드 캐시미어 오버핏 하찌 니트 커플가디건 봄 가을
#    최저가: 39,800원
#    브랜드:
#    쇼핑몰: 왓위웨어
#    링크: https://smartstore.naver.com/main/products/5290981221
#
# 16. 리스트 라운드넥 버튼 니트 가디건 TSKCDO72010
#    최저가: 23,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51143733510
#
# 17. 제너럴아이디어 GENERALIDEA WOMAN 에센셜 크루넥 가디건 4COL WBD3L04501
#    최저가: 31,416원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49541497760
#
# 18. 비비안웨스트우드 여성 베아 울 실크 가디건 1803001Z
#    최저가: 28,070원
#    브랜드: 비비안웨스트우드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/43475137325
#
# 19. 카렌 여름 가을 간절기 여자 아기가디건 유아가디건 3개월 6개월 9개월 돌아기
#    최저가: 19,800원
#    브랜드:
#    쇼핑몰: 로이앤한나
#    링크: https://smartstore.naver.com/main/products/4901850589
#
# 20. 루즈핏 캐시미어 브이넥가디건 숏 크롭 여성가디건 니트가디건 봄 간절기 레드 핑크 블랙
#    최저가: 18,900원
#    브랜드:
#    쇼핑몰: 코이블리
#    링크: https://smartstore.naver.com/main/products/4382440024
#
# 21. 허브 R 크롭트 가디건
#    최저가: 39,700원
#    브랜드: 사색
#    쇼핑몰: 사색
#    링크: https://smartstore.naver.com/main/products/11515283775
#
# 22. LE TROIS 23FW 르투아 투웨이 니트 집업 카라 가디건 2종 세트
#    최저가: 13,100원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53690259105
#
# 23. 리스트 라운드넥 루즈핏 가디건 TSKCDO72520
#    최저가: 24,940원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49580876217
#
# 24. 벤시몽 여성 케이블 니트 가디건 3종
#    최저가: 37,650원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53373694627
#
# 25. 쉬즈미스 메탈 라운드넥 니트 가디건 SSKCDO31060
#    최저가: 36,910원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49625464649
#
# 26. 로엠 브이넥 가디건 RMCKF23R98
#    최저가: 44,910원
#    브랜드: 로엠
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52675721484
#
# 27. 제너럴아이디어 제너럴 아이디어 WOMAN 멀티 스트라이프 크루넥 가디건 남색 NA WBE1L04504NA
#    최저가: 32,472원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52384299518
#
# 28. 리스트 리스트 아웃 포켓 크롭 가디건 TSKCDO70030
#    최저가: 24,020원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51690622371
#
# 29. 폴햄 여성 자켓형 가디건 PHF1EC2030
#    최저가: 28,380원
#    브랜드: 폴햄
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51964323969
#
# 30. 미쏘 에센셜 브이넥 베이직 가디건 MIWCKE920T
#    최저가: 11,690원
#    브랜드: 미쏘
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49441291447
#
# 31. 유니클로 UV PROTECTION 크루넥 여성 가디건 자외선차단 봄 간절기 빅사이즈
#    최저가: 49,800원
#    브랜드: 유니클로
#    쇼핑몰: 더헤르츠
#    링크: https://smartstore.naver.com/main/products/10061021121
#
# 32. 스파오 라운드넥 카디건 SPCKF23W01
#    최저가: 20,720원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51659066776
#
# 33. 사색 젤라 크롭트 슬림 가디건
#    최저가: 37,800원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53568688511
#
# 34. 머핀 도톰 루즈핏 숄 울니트 롱가디건 3col 봄 겨울 오버핏 고급원사 노카라 제이플로우
#    최저가: 41,800원
#    브랜드: 제이플로우
#    쇼핑몰: 제이플로우
#    링크: https://smartstore.naver.com/main/products/8103674313
#
# 35. 쉬즈미스 글리터 펀칭 브이넥 가디건 SSKCDO11080
#    최저가: 30,830원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52523460806
#
# 36. 제너럴아이디어 WOMAN 시그니처 슈퍼파인 울 케이블 가디건 4COL WBD3L04505
#    최저가: 31,000원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52131507480
#
# 37. BNX 캐릭터 자수 포인트 버튼업 니트 가디건 BW3CD009L0
#    최저가: 15,065원
#    브랜드: BNX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52483360456
#
# 38. 아울렛상품 올리브데올리브 올리브데올리브 시스루 브이넥 니트 가디건 YK4AD706
#    최저가: 24,900원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52752095274
#
# 39. 여성 여름 로브 가디건 에스닉 빅사이즈 린넨 로브 비치 멜빈트
#    최저가: 29,500원
#    브랜드:
#    쇼핑몰: 멜빈트 MELVINT
#    링크: https://smartstore.naver.com/main/products/6714235489
#
# 40. 여성 폼 플라워 꽃자수 봄 니트 가디건 빅사이즈
#    최저가: 27,300원
#    브랜드:
#    쇼핑몰: 마이이너웨어
#    링크: https://smartstore.naver.com/main/products/8223567347
#
# 41. 아기가디건 유아 여아 남아 키즈 주니어 신생아 봄 여름 가을
#    최저가: 15,300원
#    브랜드: 피카부
#    쇼핑몰: 베베드키즈
#    링크: https://smartstore.naver.com/main/products/4783455109
#
# 42. 코스에그 자수 투웨이 니트집업 가디건
#    최저가: 29,800원
#    브랜드:
#    쇼핑몰: 시크폭스
#    링크: https://www.chicfox.co.kr/index.html?branduid=511277&ref=naver_open
#
# 43. 후아유 스티브 케이블 가디건 WHCKE4901F
#    최저가: 27,810원
#    브랜드: 후아유
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49715176984
#
# 44. 린넨가디건 여름가디건 크롭가디건
#    최저가: 27,800원
#    브랜드:
#    쇼핑몰: 로우라이트
#    링크: https://smartstore.naver.com/main/products/5616478597
#
# 45. 메일리 도톰 니트 집업 세일러 카라 봄 가을 여자 여성 숏 세미 크롭 지퍼 가디건 자켓
#    최저가: 24,500원
#    브랜드:
#    쇼핑몰: 메일리Maily
#    링크: https://smartstore.naver.com/main/products/9239473338
#
# 46. 지오다노 NEW 여자 면 혼방 꽈배기 버튼 가디건 355504
#    최저가: 30,880원
#    브랜드: 지오다노
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52507346449
#
# 47. 9color 여름 얇은 비치가디건 시스루 커버업 니트 숏 크롭 가디건 화이트 블랙 핑크
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/10285474476
#
# 48. 사색 블루아 V 파인울 랩 가디건
#    최저가: 49,700원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52525143696
#
# 49. 올리브데올리브 슬림핏 브이넥 가디건 YK5SD417
#    최저가: 33,200원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52662970843
#
# 50. 봄 가을 남자 오버핏 가디건 남자니트집업 투웨이
#    최저가: 39,800원
#    브랜드: 트리플에이
#    쇼핑몰: 용된다
#    링크: https://shopping.naver.com/outlink/itemdetail/7293084017

# %%
print("\n=== 네이버 상품 ===")
idx = 1  # idx 따로 선언
for item in items_data:
    if '네이버' in item.get('mallName', ''):
        print_shop_item(idx, item)
        idx += 1  # 조건 통과할 때만 증가
# Out:
# === 네이버 상품 ===
#
# 1. 제너럴아이디어 WOMAN GNRL 에센셜 베이직 카디건 11COL WBD3L04503
#    최저가: 32,400원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53287208769
#
# 2. H&amp;M HM 파인 니트 가디건 0579541001
#    최저가: 17,512원
#    브랜드: H&M
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51781610172
#
# 3. 라코스테 남성 베이직 V넥 방모 가디건 AH560E-54N
#    최저가: 80,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49714141886
#
# 4. 벤시몽 여성 코튼 블렌드 케이블 가디건 3종
#    최저가: 44,910원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53232763110
#
# 5. 리스트 라운드넥 버튼 니트 가디건 TSKCDO72010
#    최저가: 23,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51143733510
#
# 6. 제너럴아이디어 GENERALIDEA WOMAN 에센셜 크루넥 가디건 4COL WBD3L04501
#    최저가: 31,416원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49541497760
#
# 7. 비비안웨스트우드 여성 베아 울 실크 가디건 1803001Z
#    최저가: 28,070원
#    브랜드: 비비안웨스트우드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/43475137325
#
# 8. 라코스테 여성 케이블 크루넥 가디건 AF091E-54N
#    최저가: 143,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49912758699
#
# 9. LE TROIS 23FW 르투아 투웨이 니트 집업 카라 가디건 2종 세트
#    최저가: 13,100원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53690259105
#
# 10. 리스트 라운드넥 루즈핏 가디건 TSKCDO72520
#    최저가: 24,940원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49580876217
#
# 11. 벤시몽 여성 케이블 니트 가디건 3종
#    최저가: 37,650원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53373694627
#
# 12. 쉬즈미스 메탈 라운드넥 니트 가디건 SSKCDO31060
#    최저가: 36,910원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49625464649
#
# 13. 베네통스포츠 베네통스포츠 여성 니트 가디건 2종
#    최저가: 85,980원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53126962083
#
# 14. 로엠 브이넥 가디건 RMCKF23R98
#    최저가: 44,910원
#    브랜드: 로엠
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52675721484
#
# 15. 라코스테 남성 피케 조직 V넥 울가디건 AH697E-54N
#    최저가: 174,090원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50705955349
#
# 16. 톰브라운 남성 가디건 415 MJT167A 00535
#    최저가: 671,030원
#    브랜드: 톰브라운
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52101774528
#
# 17. 제너럴아이디어 제너럴 아이디어 WOMAN 멀티 스트라이프 크루넥 가디건 남색 NA WBE1L04504NA
#    최저가: 32,472원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52384299518
#
# 18. 리스트 리스트 아웃 포켓 크롭 가디건 TSKCDO70030
#    최저가: 24,020원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51690622371
#
# 19. 폴햄 여성 자켓형 가디건 PHF1EC2030
#    최저가: 28,380원
#    브랜드: 폴햄
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51964323969
#
# 20. 미쏘 에센셜 브이넥 베이직 가디건 MIWCKE920T
#    최저가: 11,690원
#    브랜드: 미쏘
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49441291447
#
# 21. 폴로랄프로렌 폴로 랄프로렌 여성 코튼 블렌드 가디건
#    최저가: 125,400원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/45723735727
#
# 22. 제이슨우 Spring 가디건 3종
#    최저가: 74,310원
#    브랜드: 제이슨우
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52482107751
#
# 23. 아미 AMI 스몰 하트 남성 울 가디건 491 HKC001 001
#    최저가: 279,000원
#    브랜드: 아미
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50931741210
#
# 24. 셀렙샵에디션 알파카 캔디 니트가디건
#    최저가: 53,900원
#    브랜드: 셀렙샵에디션
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53020866519
#
# 25. 스파오 라운드넥 카디건 SPCKF23W01
#    최저가: 20,720원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51659066776
#
# 26. 사색 젤라 크롭트 슬림 가디건
#    최저가: 37,800원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53568688511
#
# 27. 모르간 24FW 반팔 울 니트가디건 3종 88
#    최저가: 51,460원
#    브랜드: 모르간
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50504636053
#
# 28. 쉬즈미스 글리터 펀칭 브이넥 가디건 SSKCDO11080
#    최저가: 30,830원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52523460806
#
# 29. 제너럴아이디어 WOMAN 시그니처 슈퍼파인 울 케이블 가디건 4COL WBD3L04505
#    최저가: 31,000원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52131507480
#
# 30. 타미힐피거 여성 라운드 넥 버튼 다운 긴팔 가디건 4색
#    최저가: 59,900원
#    브랜드: 타미힐피거
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/40804917010
#
# 31. BNX 캐릭터 자수 포인트 버튼업 니트 가디건 BW3CD009L0
#    최저가: 15,065원
#    브랜드: BNX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52483360456
#
# 32. 아울렛상품 올리브데올리브 올리브데올리브 시스루 브이넥 니트 가디건 YK4AD706
#    최저가: 24,900원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52752095274
#
# 33. 라삐아프 도톰 가디건 3종
#    최저가: 65,010원
#    브랜드: 라삐아프
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52482116627
#
# 34. 메종키츠네 여성 더블 폭스 헤드 가디건 H250 GW00544KT1036
#    최저가: 126,300원
#    브랜드: 메종키츠네
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50703782063
#
# 35. 후아유 스티브 케이블 가디건 WHCKE4901F
#    최저가: 27,810원
#    브랜드: 후아유
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49715176984
#
# 36. 지오다노 NEW 여자 면 혼방 꽈배기 버튼 가디건 355504
#    최저가: 30,880원
#    브랜드: 지오다노
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52507346449
#
# 37. 사색 블루아 V 파인울 랩 가디건
#    최저가: 49,700원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52525143696
#
# 38. 게스 게스진 SUZY 여성 데님믹스 입체격자 스웨터 가디건 YP1S2660
#    최저가: 137,260원
#    브랜드: 게스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53319519216
#
# 39. 올리브데올리브 슬림핏 브이넥 가디건 YK5SD417
#    최저가: 33,200원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52662970843

# %%
import requests
from bs4 import BeautifulSoup

# 벅스 뮤직 실시간 차트 URL
url = 'https://music.bugs.co.kr/chart'

# HTTP 요청 헤더 설정
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'
}

# 페이지 요청
response = requests.get(url, headers=headers)

# 응답 상태 코드 확인
if response.status_code == 200:
    # BeautifulSoup을 사용하여 HTML 파싱
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 노래 제목과 아티스트 정보를 담을 리스트 초기화
    chart_list = []
    
    # 차트 목록 선택
    songs = soup.select('table.byChart > tbody > tr')
    
    for song in songs:
        # 노래 제목 추출
        title = song.select_one('p.title > a').text.strip()
        # 아티스트 이름 추출
        artist = song.select_one('p.artist > a').text.strip()
        
        # 추출한 정보를 딕셔너리로 저장
        chart_list.append({
            'title': title,
            'artist': artist
        })
    
    # 결과 출력
    for idx, song in enumerate(chart_list, 1):
        print(f"{idx}. {song['title']} - {song['artist']}")
else:
    print(f"페이지 요청 실패: {response.status_code}")
# Out:
# 1. like JENNIE - 제니 (JENNIE)
# 2. 웃기는 소리 같겠지만 - 황치열
# 3. HOT - LE SSERAFIM (르세라핌)
# 4. TOO BAD (feat. Anderson .Paak) - G-DRAGON
# 5. Drowning - WOODZ
# 6. I DO ME - KiiiKiii (키키)
# 7. Whiplash - aespa
# 8. REBEL HEART - IVE (아이브)
# 9. 잘하고 있어 - 황치열
# 10. Love & Hate - 권진아
# 11. 1999 - 마크 (MARK)
# 12. ATTITUDE - IVE (아이브)
# 13. 나는 반딧불 - 황가람
# 14. 모르시나요(PROD.로코베리) - 조째즈
# 15. The Chase - Hearts2Hearts (하츠투하츠)
# 16. 너에게 닿기를 - 10CM
# 17. toxic till the end - 로제(ROSÉ)
# 18. Mess - 강다니엘(KANG DANIEL)
# 19. HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# 20. APT. - 로제(ROSÉ)
# 21. HAPPY - DAY6 (데이식스)
# 22. Die With A Smile - Lady GaGa(레이디 가가)
# 23. 오늘만 I LOVE YOU - BOYNEXTDOOR
# 24. 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 25. Flower - 오반(OVAN)
# 26. LOVE ATTACK - RESCENE (리센느)
# 27. 청춘만화 - 이무진
# 28. SIGN - izna (이즈나)
# 29. Supernova - aespa
# 30. Come Over - LE SSERAFIM (르세라핌)
# 31. Mantra - 제니 (JENNIE)
# 32. TAKE ME - G-DRAGON
# 33. Welcome to the Show - DAY6 (데이식스)
# 34. ExtraL (feat. Doechii) - 제니 (JENNIE)
# 35. 너와의 모든 지금 - 재쓰비 (JAESSBEE)
# 36. luther - Kendrick Lamar(켄드릭 라마)
# 37. PO￦ER - G-DRAGON
# 38. UP (KARINA Solo) - aespa
# 39. 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# 40. DRIP - BABYMONSTER
# 41. 내 이름 맑음 - QWER
# 42. 고민중독 - QWER
# 43. 미치게 그리워서 - 황가람
# 44. Magnetic - 아일릿(ILLIT)
# 45. 소나기 - 이클립스 (ECLIPSE)
# 46. 녹아내려요 - DAY6 (데이식스)
# 47. How Sweet - NewJeans
# 48. 예뻤어 - DAY6 (데이식스)
# 49. Handlebars (feat. Dua Lipa) - 제니 (JENNIE)
# 50. Armageddon - aespa
# 51. 에피소드 - 이무진
# 52. Love wins all - 아이유(IU)
# 53. 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU(악뮤)
# 54. 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# 55. 천상연 - 이창섭
# 56. 나는 아픈 건 딱 질색이니까 - (여자)아이들
# 57. earthquake - 지수(JISOO)
# 58. Cruel Summer - Taylor Swift(테일러 스위프트)
# 59. number one girl - 로제(ROSÉ)
# 60. I AM - IVE (아이브)
# 61. Supernatural - NewJeans
# 62. Congratulations - DAY6 (데이식스)
# 63. Sweet Dreams (feat. Miguel) - j-hope
# 64. Ditto - NewJeans
# 65. Love Hangover (feat. Dominic Fike) - 제니 (JENNIE)
# 66. 청혼하지 않을 이유를 못 찾았어 - 이무진
# 67. Universe - 대성
# 68. Hype Boy - NewJeans
# 69. Love me or Leave me - DAY6 (데이식스)
# 70. BEBE - STAYC(스테이씨)
# 71. Supersonic - 프로미스나인
# 72. HONEY - 황치열
# 73. Igloo - KISS OF LIFE
# 74. KNOW ABOUT ME - NMIXX
# 75. Sticky - KISS OF LIFE
# 76. After LIKE - IVE (아이브)
# 77. Not Like Us - Kendrick Lamar(켄드릭 라마)
# 78. 해야 (HEYA) - IVE (아이브)
# 79. Small girl (feat. 도경수(D.O.)) - 이영지
# 80. 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴(Paul Kim)
# 81. ETA - NewJeans
# 82. 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션(Nerd Connection)
# 83. 무제(無題) (Untitled, 2014) - G-DRAGON
# 84. 숙녀에게 - 송필근
# 85. 비의 랩소디 - 임재현
# 86. Bubble Gum - NewJeans
# 87. Letter To Myself - 태연 (TAEYEON)
# 88. 슬픈 초대장 - 순순희 (지환)
# 89. 사랑인가 봐 - 멜로망스(MeloMance)
# 90. Attention - NewJeans
# 91. 너의 모든 순간 - 성시경
# 92. Cherish (My Love) - 아일릿(ILLIT)
# 93. 숲 - 최유리
# 94. 인사 - 범진
# 95. Live My Life - aespa
# 96. 사건의 지평선 - 윤하(Younha/ユンナ)
# 97. 주저하는 연인들을 위해 - 잔나비
# 98. LOVE DIVE - IVE (아이브)
# 99. 있는 모습 그대로 - 로이킴
# 100. To. X - 태연 (TAEYEON)
