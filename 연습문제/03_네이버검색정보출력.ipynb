# %%
import requests
import os
from dotenv import load_dotenv
from pprint import pprint

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret,
}

# query string 문자열을 dict 선언
payload = {
    'query': '파이썬',
    'display': 10,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/book.json' #?query=파이썬&display=100&sort=sim

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기
items_data = res.json()['items']

pprint(items_data)

# %%
print("\n=== 추천 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    price = int(book.get('discount',0))  # price 없으면 0 처리
    pubdate = book.get('pubdate', '')
    pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:]}"

    print(f"\n{idx}. {book['title']}")
    print(f"   저자: {book['author']}")
    print(f"   출판사: {book['publisher']}")
    print(f"   출판일: {pubdate}")
    print(f"   가격: {price:,}원")
    print(f"   설명: {book['description'][:100]}...")  # 100자만 출력

# %%
print("\n=== 인피니티북스 출판 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    if '인피니티북스' in book['publisher']:
        price = int(book.get('discount', 0))
        pubdate = book.get('pubdate', '')
        if len(pubdate) == 8:
            pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:]}"
        else:
            pubdate = "출판일 정보 없음"

        print(f"\n{idx}. {book['title']}")
        print(f"   저자: {book['author']}")
        print(f"   출판사: {book['publisher']}")
        print(f"   출판일: {pubdate}")
        print(f"   가격: {price:,}원")
        print(f"   설명: {book['description'][:100]}...")
# Out:
# === 인피니티북스 출판 도서 목록 ===
#
# 8. 파이썬
#    저자: 천인국
#    출판사: 인피니티북스
#    출판일: 2017-08-30
#    가격: 10,800원
#    설명: 컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨...

# %%
print("\n=== 가격이 20,000원 이상인 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    price = int(book.get('discount', 0))
    if price >= 20000:
        pubdate = book.get('pubdate', '')
        if len(pubdate) == 8:
            pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:]}"
        else:
            pubdate = "출판일 정보 없음"

        print(f"\n{idx}. {book['title']}")
        print(f"   저자: {book['author']}")
        print(f"   출판사: {book['publisher']}")
        print(f"   출판일: {pubdate}")
        print(f"   가격: {price:,}원")
        print(f"   설명: {book['description'][:100]}...")
# Out:
# === 가격이 20,000원 이상인 도서 목록 ===
#
# 1. 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
#    저자: 문현일
#    출판사: 한빛미디어
#    출판일: 2025-02-14
#    가격: 23,400원
#    설명: “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”
# 나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등
# 생활 속  15가지 파이썬 프...
#
# 4. 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
#    저자: 사이토 고키
#    출판사: 한빛미디어
#    출판일: 2025-01-24
#    가격: 23,400원
#    설명: 딥러닝 분야 부동의 베스트셀러!
# 머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서
#
# 이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수...
#
# 5. 파이썬
#    저자: 홍의경
#    출판사: 생능출판
#    출판일: 2022-03-09
#    가격: 29,440원
#    설명: 코딩 실력을 키우는 지름길은 실습이다.
#
# 2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 교과서가 검인정에 합격하였는데...

# %%
print("\n=== JSON 파일로 저장 ===")

import json

with open('python_books.json', 'w', encoding='utf-8') as f:
    json.dump(items_data, f, ensure_ascii=False, indent=2)

print("JSON 저장 완료!")
# Out:
# === JSON 파일로 저장 ===
# JSON 저장 완료!

# %%
def print_book(idx, book):
    price = int(book.get('discount', 0))
    pubdate = book.get('pubdate', '')
    pubdate = f"{pubdate[:4]}-{pubdate[4:6]}-{pubdate[6:]}" if len(pubdate) == 8 else "출판일 정보 없음"

    print(f"\n{idx}. {book['title']}")
    print(f"   저자: {book['author']}")
    print(f"   출판사: {book['publisher']}")
    print(f"   출판일: {pubdate}")
    print(f"   가격: {price:,}원")
    print(f"   설명: {book['description'][:100]}...")

# %%
print("\n=== 추천 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    print_book(idx, book)
# Out:
# === 추천 도서 목록 ===
#
# 1. 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
#    저자: 문현일
#    출판사: 한빛미디어
#    출판일: 2025-02-14
#    가격: 23,400원
#    설명: “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”
# 나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등
# 생활 속  15가지 파이썬 프...
#
# 2. 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
#    저자: 윤인성
#    출판사: 한빛미디어
#    출판일: 2022-06-01
#    가격: 19,800원
#    설명: 혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서
#
# 『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따...
#
# 3. Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
#    저자: 박응용
#    출판사: 이지스퍼블리싱
#    출판일: 2023-06-15
#    가격: 19,800원
#    설명: 프로그래밍 분야 8년 연속 베스트셀러!
# 《Do it! 점프 투 파이썬》 전면 개정 2판 출시!
#
# 중고등학생도, 비전공자도, 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개...
#
# 4. 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
#    저자: 사이토 고키
#    출판사: 한빛미디어
#    출판일: 2025-01-24
#    가격: 23,400원
#    설명: 딥러닝 분야 부동의 베스트셀러!
# 머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서
#
# 이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수...
#
# 5. 파이썬
#    저자: 홍의경
#    출판사: 생능출판
#    출판일: 2022-03-09
#    가격: 29,440원
#    설명: 코딩 실력을 키우는 지름길은 실습이다.
#
# 2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 교과서가 검인정에 합격하였는데...
#
# 6. CODING BASICS PYTHON (파이썬)
#    저자: 김상민^장성식^김일태
#    출판사: 렉스미디어닷넷
#    출판일: 2022-02-10
#    가격: 18,000원
#    설명: 파이썬으로 다지는 프로그래밍의 기초
#
# ㆍ 다양한 예제를 활용하여 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 파이썬 입문서입니다.
# ㆍ 문법을 사전식으로 나열하지 않고 기능적인 ...
#
# 7. 파이썬 (제2판)
#    저자: 염기원^오지영
#    출판사: 북두
#    출판일: 2022-01-20
#    가격: 16,200원
#    설명: 책의 전반부는 비전공자의 입장에서 비전공자를 위한 파이썬 프로그래밍의 기초적인 내용으로 구성되어 있다. 프로그래밍에 익숙하거나 파이썬 경험이 있는 독자들은 곧바로 책의 후반부를 공...
#
# 8. 파이썬
#    저자: 천인국
#    출판사: 인피니티북스
#    출판일: 2017-08-30
#    가격: 10,800원
#    설명: 컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨...
#
# 9. 파이썬 (비전공자를위한 파이썬 기초 입문서)
#    저자: 김명호
#    출판사: 에듀웨이
#    출판일: 2019-05-25
#    가격: 16,200원
#    설명: 막막했던 파이썬, 이제 한 권으로 기초를 배우는
# 파이썬 사용 설명서!
#
# 전 세계적으로 유명한 구글(Google)이 자신의 많은 서비스를 파이썬으로 제공하고 있습니다. 이것은 구글의...
#
# 10. 파이썬
#    저자: 염기원
#    출판사: 복두출판사
#    출판일: 2020-08-20
#    가격: 0원
#    설명: 비전공자의 데이터 분석을 위한 『파이썬』은 〈파이썬 기초〉, 〈파이썬을 이용한 데이터 분석 기초〉, 〈시각화 라이브러리 사용하기〉 등 파이썬의 기초적이고 전반적인 내용이 수록되어 ...

# %%
print("\n=== 한빛미디어 출판 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    if '한빛미디어' in book['publisher']:
        print_book(idx, book)
# Out:
# === 한빛미디어 출판 도서 목록 ===
#
# 1. 혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)
#    저자: 문현일
#    출판사: 한빛미디어
#    출판일: 2025-02-14
#    가격: 23,400원
#    설명: “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”
# 나의 신용카드 내역 분석, 우리 아파트 실거래가 시각화해보기, 맛집 지도 웹 앱 만들기 등
# 생활 속  15가지 파이썬 프...
#
# 2. 혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
#    저자: 윤인성
#    출판사: 한빛미디어
#    출판일: 2022-06-01
#    가격: 19,800원
#    설명: 혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서
#
# 『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따...
#
# 4. 밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
#    저자: 사이토 고키
#    출판사: 한빛미디어
#    출판일: 2025-01-24
#    가격: 23,400원
#    설명: 딥러닝 분야 부동의 베스트셀러!
# 머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 입문서
#
# 이 책은 딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수...

# %%
print("\n=== 가격이 20,000원 이하인 도서 목록 ===")
for idx, book in enumerate(items_data, 1):
    price = int(book.get('discount', 0))
    if price <= 20000:
        print_book(idx, book)

# %%
import requests
import os
from dotenv import load_dotenv
from pprint import pprint

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret,
}

# query string 문자열을 dict 선언
payload = {
    'query': '가디건',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/shop.json' #?query=파이썬&display=100&sort=sim

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기
items_data = res.json()['items']

pprint(items_data)

# %%
def print_shop_item(idx, item):
    lprice = int(item.get('lprice', 0))
    print(f"\n{idx}. {item['title'].replace('<b>', '').replace('</b>', '')}")
    print(f"   최저가: {lprice:,}원")
    print(f"   브랜드: {item.get('brand', '정보없음')}")
    print(f"   쇼핑몰: {item.get('mallName', '정보없음')}")
    print(f"   링크: {item['link']}")

# %%
print("\n=== 쇼핑 검색 결과 ===")
for idx, item in enumerate(items_data, 1):
    print_shop_item(idx, item)

# %%
print("\n=== 50,000원 이하 상품 ===")
idx = 1
for item in items_data:
    if int(item.get('lprice', 0)) <= 50000:
        print_shop_item(idx, item)
        idx += 1  # 조건 통과할 때만 증가
# Out:
# === 50,000원 이하 상품 ===
#
# 1. 봄 가을 간절기 라운드 루즈핏 크롭 가디건 레드 그린 핑크 화이트 블랙 옐로우
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/5466947569
#
# 2. 부드러운 캐시미어 크롭 가디건 숏 라운드 니트가디건 여성 가디건 봄 간절기 레드 핑크
#    최저가: 18,900원
#    브랜드:
#    쇼핑몰: 코이블리
#    링크: https://smartstore.naver.com/main/products/4828155463
#
# 3. 10COLOR 여성 봄 비비드컬러 라운드 슬릿넥 크롭 니트 그린 핑크가디건
#    최저가: 24,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/9959540751
#
# 4. 제너럴아이디어 WOMAN GNRL 에센셜 베이직 카디건 11COL WBD3L04503
#    최저가: 33,600원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53287208769
#
# 5. 여자 보풀없는 캐시미어 비스코스 니트 여성 라운드 가디건 인디핑크 병원 간호 사무실
#    최저가: 29,900원
#    브랜드:
#    쇼핑몰: 지읒이응
#    링크: https://smartstore.naver.com/main/products/5391580059
#
# 6. H&amp;M HM 파인 니트 가디건 0579541001
#    최저가: 17,512원
#    브랜드: H&M
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51781610172
#
# 7. 레이어드가디건 캐시미어가디건 여자봄가디건 사무실
#    최저가: 29,800원
#    브랜드:
#    쇼핑몰: 미드시티 여성니트
#    링크: https://smartstore.naver.com/main/products/10064618231
#
# 8. 남자가디건 울 라운드 캐시미어 오버핏 하찌 니트 커플가디건 봄 가을
#    최저가: 39,800원
#    브랜드:
#    쇼핑몰: 왓위웨어
#    링크: https://smartstore.naver.com/main/products/5290981221
#
# 9. (당일) 프리티영띵 뉴 페블 골지 가디건 PYT 프영띵 떠유니
#    최저가: 42,000원
#    브랜드:
#    쇼핑몰: ttoyuni
#    링크: https://smartstore.naver.com/main/products/9044880794
#
# 10. 드온도 노튼 캐시미어 가디건 봄 스프링 라운드 니트 deondo
#    최저가: 49,500원
#    브랜드:
#    쇼핑몰: 루나드엘
#    링크: https://smartstore.naver.com/main/products/9971634198
#
# 11. 시스루 얇은 린넨 루즈핏 니트 여름 여성 가디건 (올타임)
#    최저가: 23,900원
#    브랜드:
#    쇼핑몰: 고고하니
#    링크: https://smartstore.naver.com/main/products/5592080655
#
# 12. 예가체프 R 파인울 가디건
#    최저가: 43,700원
#    브랜드: 사색
#    쇼핑몰: 사색
#    링크: https://smartstore.naver.com/main/products/11333309394
#
# 13. 비비안웨스트우드 여성 베아 울 실크 가디건 1803001Z
#    최저가: 23,840원
#    브랜드: 비비안웨스트우드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/43475137325
#
# 14. 벤시몽 여성 코튼 블렌드 케이블 가디건 3종
#    최저가: 44,910원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53232763110
#
# 15. 포인즈 부드럽고 포근해 얇은 니트 울 오버핏 가디건 여성 가디건 겨울 봄
#    최저가: 24,800원
#    브랜드:
#    쇼핑몰: 베이지블랑.
#    링크: https://smartstore.naver.com/main/products/5194780033
#
# 16. 유니클로 UV PROTECTION 크루넥 여성 가디건 자외선차단 봄 간절기 빅사이즈
#    최저가: 49,800원
#    브랜드: 유니클로
#    쇼핑몰: 더헤르츠
#    링크: https://smartstore.naver.com/main/products/10061021121
#
# 17. 제너럴아이디어 GENERALIDEA WOMAN 에센셜 크루넥 가디건 4COL WBD3L04501
#    최저가: 31,416원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49541497760
#
# 18. 벤시몽 여성 케이블 니트 가디건 3종
#    최저가: 37,650원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53373694627
#
# 19. 쉬즈미스 메탈 라운드넥 니트 가디건 SSKCDO31060
#    최저가: 36,910원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49625464649
#
# 20. 리스트 라운드넥 버튼 니트 가디건 TSKCDO72010
#    최저가: 23,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51143733510
#
# 21. 머핀 도톰 루즈핏 숄 울니트 롱가디건 3col 봄 겨울 오버핏 고급원사 노카라 제이플로우
#    최저가: 41,800원
#    브랜드: 제이플로우
#    쇼핑몰: 제이플로우
#    링크: https://smartstore.naver.com/main/products/8103674313
#
# 22. 카렌 여름 가을 간절기 여자 아기가디건 유아가디건 3개월 6개월 9개월 돌아기
#    최저가: 19,800원
#    브랜드:
#    쇼핑몰: 로이앤한나
#    링크: https://smartstore.naver.com/main/products/4901850589
#
# 23. 티블러썸 결혼식 하객룩 진주단추 가디건 봄 퍼프 니트 여성 금장 크롭 가디건 6color
#    최저가: 27,000원
#    브랜드:
#    쇼핑몰: 건강한생활82
#    링크: https://smartstore.naver.com/main/products/7984870784
#
# 24. 루즈핏 캐시미어 브이넥가디건 숏 크롭 여성가디건 니트가디건 봄 간절기 레드 핑크 블랙
#    최저가: 18,900원
#    브랜드:
#    쇼핑몰: 코이블리
#    링크: https://smartstore.naver.com/main/products/4382440024
#
# 25. 허브 R 크롭트 가디건
#    최저가: 39,700원
#    브랜드: 사색
#    쇼핑몰: 사색
#    링크: https://smartstore.naver.com/main/products/11515283775
#
# 26. 폴햄 여성 자켓형 가디건 PHF1EC2030
#    최저가: 29,900원
#    브랜드: 폴햄
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51964323969
#
# 27. 제너럴아이디어 제너럴 아이디어 WOMAN 멀티 스트라이프 크루넥 가디건 남색 NA WBE1L04504NA
#    최저가: 32,472원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52384299518
#
# 28. LE TROIS 23FW 르투아 투웨이 니트 집업 카라 가디건 2종 세트
#    최저가: 13,100원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53690259105
#
# 29. 리스트 라운드넥 루즈핏 가디건 TSKCDO72520
#    최저가: 24,280원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49580876217
#
# 30. 미쏘 에센셜 브이넥 베이직 가디건 MIWCKE920T
#    최저가: 11,690원
#    브랜드: 미쏘
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49441291447
#
# 31. 리스트 리스트 아웃 포켓 크롭 가디건 TSKCDO70030
#    최저가: 24,020원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51690622371
#
# 32. 스파오 라운드넥 카디건 SPCKF23W01
#    최저가: 25,848원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51659066776
#
# 33. 모르간 24FW 반팔 울 니트가디건 3종 88
#    최저가: 37,160원
#    브랜드: 모르간
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50504636053
#
# 34. 로엠 브이넥 가디건 RMCKF23R98
#    최저가: 44,910원
#    브랜드: 로엠
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52675721484
#
# 35. 사색 젤라 크롭트 슬림 가디건
#    최저가: 37,800원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53568688511
#
# 36. BNX 캐릭터 자수 포인트 버튼업 니트 가디건 BW3CD009L0
#    최저가: 15,065원
#    브랜드: BNX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52483360456
#
# 37. 제너럴아이디어 WOMAN 시그니처 슈퍼파인 울 케이블 가디건 4COL WBD3L04505
#    최저가: 31,000원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52131507480
#
# 38. 아울렛상품 올리브데올리브 올리브데올리브 시스루 브이넥 니트 가디건 YK4AD706
#    최저가: 24,900원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52752095274
#
# 39. 봄 가을 남자 오버핏 가디건 남자니트집업 투웨이
#    최저가: 39,800원
#    브랜드: 트리플에이
#    쇼핑몰: 용된다
#    링크: https://shopping.naver.com/outlink/itemdetail/7293084017
#
# 40. 여성 폼 플라워 꽃자수 봄 니트 가디건 빅사이즈
#    최저가: 27,500원
#    브랜드:
#    쇼핑몰: 마이이너웨어
#    링크: https://smartstore.naver.com/main/products/8223567347
#
# 41. 코스에그 자수 투웨이 니트집업 가디건
#    최저가: 29,800원
#    브랜드:
#    쇼핑몰: 시크폭스
#    링크: https://www.chicfox.co.kr/index.html?branduid=511277&ref=naver_open
#
# 42. 사색 블루아 V 파인울 랩 가디건
#    최저가: 49,700원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52525143696
#
# 43. 9color 여름 얇은 비치가디건 시스루 커버업 니트 숏 크롭 가디건 화이트 블랙 핑크
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/10285474476
#
# 44. 가디건어깨 숄 니트가디건 페이크가디건
#    최저가: 14,800원
#    브랜드:
#    쇼핑몰: 인생옷장
#    링크: https://smartstore.naver.com/main/products/9894857032
#
# 45. 여성 여름 로브 가디건 에스닉 빅사이즈 린넨 로브 비치 멜빈트
#    최저가: 29,500원
#    브랜드:
#    쇼핑몰: 멜빈트 MELVINT
#    링크: https://smartstore.naver.com/main/products/6714235489
#
# 46. 쉬즈미스 글리터 펀칭 브이넥 가디건 SSKCDO11080
#    최저가: 30,830원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52523460806
#
# 47. 스파오 소프트얀 케이블 라운드넥 카디건 SPCKE49W11
#    최저가: 15,900원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49686421611
#
# 48. 66~120 봄,가을 간절기 오버핏 롱가디건 빅사이즈
#    최저가: 16,700원
#    브랜드:
#    쇼핑몰: 오다오
#    링크: https://smartstore.naver.com/main/products/5106322034
#
# 49. 후아유 스티브 케이블 가디건 WHCKE4901F
#    최저가: 27,810원
#    브랜드: 후아유
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49715176984
#
# 50. 메일리 도톰 니트 집업 세일러 카라 봄 가을 여자 여성 숏 세미 크롭 지퍼 가디건 자켓
#    최저가: 24,500원
#    브랜드:
#    쇼핑몰: 메일리Maily
#    링크: https://smartstore.naver.com/main/products/9239473338
#
# 51. 오즈키즈 유아 아기 가디건 남아 여아 키즈 가디건
#    최저가: 19,900원
#    브랜드: 오즈키즈
#    쇼핑몰: 오즈키즈
#    링크: https://smartstore.naver.com/main/products/7999612471

# %%
print("\n=== 네이버 상품 ===")
idx = 1  # idx 따로 선언
for item in items_data:
    if '네이버' in item.get('mallName', ''):
        print_shop_item(idx, item)
        idx += 1  # 조건 통과할 때만 증가
# Out:
# === 네이버 상품 ===
#
# 1. 제너럴아이디어 WOMAN GNRL 에센셜 베이직 카디건 11COL WBD3L04503
#    최저가: 33,600원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53287208769
#
# 2. H&amp;M HM 파인 니트 가디건 0579541001
#    최저가: 17,512원
#    브랜드: H&M
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51781610172
#
# 3. 비비안웨스트우드 여성 베아 울 실크 가디건 1803001Z
#    최저가: 23,840원
#    브랜드: 비비안웨스트우드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/43475137325
#
# 4. 벤시몽 여성 코튼 블렌드 케이블 가디건 3종
#    최저가: 44,910원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53232763110
#
# 5. 라코스테 남성 피케 조직 V넥 울가디건 AH697E-54N
#    최저가: 167,440원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50705955349
#
# 6. 제너럴아이디어 GENERALIDEA WOMAN 에센셜 크루넥 가디건 4COL WBD3L04501
#    최저가: 31,416원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49541497760
#
# 7. 라코스테 남성 베이직 V넥 방모 가디건 AH560E-54N
#    최저가: 80,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49714141886
#
# 8. 벤시몽 여성 케이블 니트 가디건 3종
#    최저가: 37,650원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53373694627
#
# 9. 쉬즈미스 메탈 라운드넥 니트 가디건 SSKCDO31060
#    최저가: 36,910원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49625464649
#
# 10. 리스트 라운드넥 버튼 니트 가디건 TSKCDO72010
#    최저가: 23,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51143733510
#
# 11. 셀렙샵에디션 알파카 캔디 니트가디건
#    최저가: 53,900원
#    브랜드: 셀렙샵에디션
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53020866519
#
# 12. 톰브라운 남성 가디건 415 MJT167A 00535
#    최저가: 671,030원
#    브랜드: 톰브라운
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52101774528
#
# 13. 폴햄 여성 자켓형 가디건 PHF1EC2030
#    최저가: 29,900원
#    브랜드: 폴햄
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51964323969
#
# 14. 제너럴아이디어 제너럴 아이디어 WOMAN 멀티 스트라이프 크루넥 가디건 남색 NA WBE1L04504NA
#    최저가: 32,472원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52384299518
#
# 15. 라코스테 여성 케이블 크루넥 가디건 AF091E-54N
#    최저가: 143,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49912758699
#
# 16. LE TROIS 23FW 르투아 투웨이 니트 집업 카라 가디건 2종 세트
#    최저가: 13,100원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53690259105
#
# 17. 리스트 라운드넥 루즈핏 가디건 TSKCDO72520
#    최저가: 24,280원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49580876217
#
# 18. 미쏘 에센셜 브이넥 베이직 가디건 MIWCKE920T
#    최저가: 11,690원
#    브랜드: 미쏘
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49441291447
#
# 19. 제이슨우 Spring 가디건 3종
#    최저가: 74,310원
#    브랜드: 제이슨우
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52482107751
#
# 20. 리스트 리스트 아웃 포켓 크롭 가디건 TSKCDO70030
#    최저가: 24,020원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51690622371
#
# 21. 스파오 라운드넥 카디건 SPCKF23W01
#    최저가: 25,848원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51659066776
#
# 22. 메종키츠네 여성 더블 폭스 헤드 가디건 H250 GW00544KT1036
#    최저가: 126,300원
#    브랜드: 메종키츠네
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50703782063
#
# 23. 모르간 24FW 반팔 울 니트가디건 3종 88
#    최저가: 37,160원
#    브랜드: 모르간
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50504636053
#
# 24. 로엠 브이넥 가디건 RMCKF23R98
#    최저가: 44,910원
#    브랜드: 로엠
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52675721484
#
# 25. 폴로랄프로렌 폴로 랄프로렌 여성 코튼 블렌드 가디건
#    최저가: 125,400원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/45723735727
#
# 26. 아미 AMI 스몰 하트 남성 울 가디건 491 HKC001 001
#    최저가: 279,000원
#    브랜드: 아미
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50931741210
#
# 27. 사색 젤라 크롭트 슬림 가디건
#    최저가: 37,800원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53568688511
#
# 28. 타미힐피거 여성 라운드 넥 버튼 다운 긴팔 가디건 4색
#    최저가: 59,900원
#    브랜드: 타미힐피거
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/40804917010
#
# 29. BNX 캐릭터 자수 포인트 버튼업 니트 가디건 BW3CD009L0
#    최저가: 15,065원
#    브랜드: BNX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52483360456
#
# 30. 제너럴아이디어 WOMAN 시그니처 슈퍼파인 울 케이블 가디건 4COL WBD3L04505
#    최저가: 31,000원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52131507480
#
# 31. 아울렛상품 올리브데올리브 올리브데올리브 시스루 브이넥 니트 가디건 YK4AD706
#    최저가: 24,900원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52752095274
#
# 32. 베네통스포츠 베네통스포츠 여성 니트 가디건 2종
#    최저가: 85,980원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53126962083
#
# 33. 타미힐피거 여성 라운드넥 케이블 가디건
#    최저가: 56,910원
#    브랜드: 타미힐피거
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50798194985
#
# 34. 사색 블루아 V 파인울 랩 가디건
#    최저가: 49,700원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52525143696
#
# 35. 쉬즈미스 글리터 펀칭 브이넥 가디건 SSKCDO11080
#    최저가: 30,830원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52523460806
#
# 36. 스파오 소프트얀 케이블 라운드넥 카디건 SPCKE49W11
#    최저가: 15,900원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49686421611
#
# 37. 폴로 여성 피마 코튼 가디건
#    최저가: 74,610원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53042166323
#
# 38. 후아유 스티브 케이블 가디건 WHCKE4901F
#    최저가: 27,810원
#    브랜드: 후아유
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49715176984
#
# 39. 게스 게스진 SUZY 여성 데님믹스 입체격자 스웨터 가디건 YP1S2660
#    최저가: 137,260원
#    브랜드: 게스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53319519216

# %%
import requests
from bs4 import BeautifulSoup

# 벅스 뮤직 실시간 차트 URL
url = 'https://music.bugs.co.kr/chart'

# HTTP 요청 헤더 설정
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'
}

# 페이지 요청
response = requests.get(url, headers=headers)

# 응답 상태 코드 확인
if response.status_code == 200:
    # BeautifulSoup을 사용하여 HTML 파싱
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 노래 제목과 아티스트 정보를 담을 리스트 초기화
    chart_list = []
    
    # 차트 목록 선택
    songs = soup.select('table.byChart > tbody > tr')
    
    for song in songs:
        # 노래 제목 추출
        title = song.select_one('p.title > a').text.strip()
        # 아티스트 이름 추출
        artist = song.select_one('p.artist > a').text.strip()
        
        # 추출한 정보를 딕셔너리로 저장
        chart_list.append({
            'title': title,
            'artist': artist
        })
    
    # 결과 출력
    for idx, song in enumerate(chart_list, 1):
        print(f"{idx}. {song['title']} - {song['artist']}")
else:
    print(f"페이지 요청 실패: {response.status_code}")
# Out:
# 1. like JENNIE - 제니 (JENNIE)
# 2. 웃기는 소리 같겠지만 - 황치열
# 3. TOO BAD (feat. Anderson .Paak) - G-DRAGON
# 4. Drowning - WOODZ
# 5. HOT - LE SSERAFIM (르세라핌)
# 6. I DO ME - KiiiKiii (키키)
# 7. Mess - 강다니엘(KANG DANIEL)
# 8. REBEL HEART - IVE (아이브)
# 9. Whiplash - aespa
# 10. 나는 반딧불 - 황가람
# 11. 터져 나올 것 같지만 - 황치열
# 12. 모르시나요(PROD.로코베리) - 조째즈
# 13. ATTITUDE - IVE (아이브)
# 14. toxic till the end - 로제(ROSÉ)
# 15. 너에게 닿기를 - 10CM
# 16. HAPPY - DAY6 (데이식스)
# 17. Die With A Smile - Lady GaGa(레이디 가가)
# 18. APT. - 로제(ROSÉ)
# 19. 오늘만 I LOVE YOU - BOYNEXTDOOR
# 20. HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# 21. The Chase - Hearts2Hearts (하츠투하츠)
# 22. ExtraL (feat. Doechii) - 제니 (JENNIE)
# 23. 1999 - 마크 (MARK)
# 24. 청춘만화 - 이무진
# 25. 주저하는 연인들을 위해 - 잔나비
# 26. 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# 27. Mantra - 제니 (JENNIE)
# 28. TAKE ME - G-DRAGON
# 29. KNOW ABOUT ME - NMIXX
# 30. Small girl (feat. 도경수(D.O.)) - 이영지
# 31. 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 32. Flower - 오반(OVAN)
# 33. Supernova - aespa
# 34. Cherish (My Love) - 아일릿(ILLIT)
# 35. 녹아내려요 - DAY6 (데이식스)
# 36. 너의 모든 순간 - 성시경
# 37. 미치게 그리워서 - 황가람
# 38. PO￦ER - G-DRAGON
# 39. LOVE DIVE - IVE (아이브)
# 40. Welcome to the Show - DAY6 (데이식스)
# 41. ETA - NewJeans
# 42. 사랑인가 봐 - 멜로망스(MeloMance)
# 43. LOVE ATTACK - RESCENE (리센느)
# 44. 슬픈 초대장 - 순순희 (지환)
# 45. 소나기 - 이클립스 (ECLIPSE)
# 46. 인사 - 범진
# 47. 고민중독 - QWER
# 48. 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴(Paul Kim)
# 49. 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# 50. 에피소드 - 이무진
# 51. DRIP - BABYMONSTER
# 52. To. X - 태연 (TAEYEON)
# 53. 숲 - 최유리
# 54. Magnetic - 아일릿(ILLIT)
# 55. luther - Kendrick Lamar(켄드릭 라마)
# 56. Handlebars (feat. Dua Lipa) - 제니 (JENNIE)
# 57. number one girl - 로제(ROSÉ)
# 58. UP (KARINA Solo) - aespa
# 59. How Sweet - NewJeans
# 60. 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU(악뮤)
# 61. Supernatural - NewJeans
# 62. I AM - IVE (아이브)
# 63. 너와의 모든 지금 - 재쓰비 (JAESSBEE)
# 64. After LIKE - IVE (아이브)
# 65. ZEN - 제니 (JENNIE)
# 66. Armageddon - aespa
# 67. Cruel Summer - Taylor Swift(테일러 스위프트)
# 68. Sticky - KISS OF LIFE
# 69. Congratulations - DAY6 (데이식스)
# 70. Igloo - KISS OF LIFE
# 71. Not Like Us - Kendrick Lamar(켄드릭 라마)
# 72. Bubble Gum - NewJeans
# 73. 무제(無題) (Untitled, 2014) - G-DRAGON
# 74. 예뻤어 - DAY6 (데이식스)
# 75. 내 이름 맑음 - QWER
# 76. Supersonic - 프로미스나인
# 77. Love wins all - 아이유(IU)
# 78. 비의 랩소디 - 임재현
# 79. 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션(Nerd Connection)
# 80. Come Over - LE SSERAFIM (르세라핌)
# 81. 나는 아픈 건 딱 질색이니까 - (여자)아이들
# 82. Hype Boy - NewJeans
# 83. 청혼하지 않을 이유를 못 찾았어 - 이무진
# 84. 숙녀에게 - 송필근
# 85. 사건의 지평선 - 윤하(Younha/ユンナ)
# 86. 천상연 - 이창섭
# 87. Attention - NewJeans
# 88. Ditto - NewJeans
# 89. Sweet Dreams (feat. Miguel) - j-hope
# 90. 있는 모습 그대로 - 로이킴
# 91. Love me or Leave me - DAY6 (데이식스)
# 92. BEBE - STAYC(스테이씨)
# 93. Love Hangover (feat. Dominic Fike) - 제니 (JENNIE)
# 94. 밤양갱 - 비비(BIBI)
# 95. Letter To Myself - 태연 (TAEYEON)
# 96. Live My Life - aespa
# 97. 해야 (HEYA) - IVE (아이브)
# 98. earthquake - 지수(JISOO)
# 99. 커플 (Couple) - 정은지
# 100. Universe - 대성
